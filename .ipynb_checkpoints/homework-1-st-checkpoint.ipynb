# %% [markdown]
# # Домашнее задание 1. Сбор данных

# %% [markdown]
# При решении реальных задач мы почти никогда не имеем дело с "хорошими" исходными данными, уже подготовленными для обработки и анализа. Как правило на входе имеются неструкткрированные данные в "грязном" виде, например необработанные тексты, изображения или аудио файлы. Иногда нет даже этого, и данные приходится собирать из разных доступных источников: разнообразных баз данных, внешних сервисов и даже электронных таблиц. После того, как данные получены, их унифицируют, очищают от шума, преобразовывают в нужный вид и сохраняют для дальнейшего анализа. В одном из традиционных подходов к [Data Mining](http://www.wikiwand.com/en/Online_analytical_processing) этот процесс называется Extract-Transform-Load ([ETL](http://www.wikiwand.com/en/Extract,_transform,_load)).
#
# Цель этого задания собрать первые данные о пользователях из обучающей выборки и провести простейший качественный анализ. В ходе решения будут использованы:
# 1. [numpy](http://www.numpy.org/) -- библиотека для работы с многомерными массивами
# 2. [pandas](http://pandas.pydata.org/) -- библиотека, позволяющая удобно работать с различными типами данных
# 3. [requests](http://docs.python-requests.org/en/latest/) -- библиотека, которую можно использовать для вызова HTTP запросов
# 4. [python-twitter](https://github.com/bear/python-twitter/tree/master/twitter) -- обертка для Twitter API
# 5. [matplotlib](http://matplotlib.org/) -- библиотека для рисования графиков в python
#
# Первым делом импортируем необходимые библиотеки и убеждаемся, что все установлено.

# %%
import pandas as pd
import numpy as np
import pylab as pl
import twitter
import requests
import datetime
import dateutil
import csv
import os
import json
import mpl_toolkits.basemap as bm

# Plotting config
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Чтение исходных данных из файла

# %% [markdown]
# Считываем исходные данные из файла в data frame библиотеки pandas. Полученный data frame должен иметь целочисленный ключ и две колонки:
# 1. uid -- идентификатор пользователя
# 2. cat -- числовой номер класса

# %%
TRAINING_SET_PATH = "train.csv"
TESTING_SET_PATH = "test.csv"
df_users_train = pd.read_csv(TRAINING_SET_PATH, sep=",", header=0)
df_users_ex = pd.read_csv(TESTING_SET_PATH, sep=",", header=0)
df_users_ex['cls'] = None
df_users = pd.concat([df_users_train, df_users_ex])
df_users.head()
# Out:
#           uid  cls
# 0   202388889  1.0
# 1  1392518336  0.0
# 2   361208576  1.0
# 3  1535215357  1.0
# 4  4396196375  1.0

# %% [markdown]
# Построим распределение целевой переменной. Требуется получить [barchart](http://www.wikiwand.com/en/Bar_chart), в котором высота столбика, соответствующего каждому из классов, пропорциональна количеству пользователей этого класса. По горизонтальной оси отложены классы (positive, negative), а по вертикальной -- количество пользователей.

# %%
# Compute the distribution of the target variable
counts, bins = np.histogram(df_users_train["cls"], bins=[0,1,2])

# Plot the distribution
pl.figure(figsize=(6,6))
pl.bar(bins[:-1], counts, width=0.5, alpha=0.4)
pl.xticks(bins[:-1] + 0.3, ["negative", "positive"])
pl.xlim(bins[0] - 0.5, bins[-1])
pl.ylabel("Number of users")
pl.title("Target variable distribution")
pl.show()

# %% [markdown]
# ## Сбор данных

# %% [markdown]
# Для того чтобы разработать модель, которая предсказывает значение целевой переменной для произвольного пользователя, недостаточно знать только значения идентификаторов пользоватей. Причина в том, что _user_id_ для пользователя никак не зависит от целевой переменной -- идентификатор генерируется на основании времени регистрации, сервера, обрабатывающего запрос, и номера пользователя ([подробности](https://dev.twitter.com/overview/api/twitter-ids-json-and-snowflake)).
#
# Поэтому нам потребуется загрузить дополнительную информацию о каждом пользователе, иначе говоря провести сбор данных (data collection). Наиболее важную информацию можно загрузить из [Twitter](https://dev.twitter.com/rest/public) [API](http://www.wikiwand.com/en/Representational_state_transfer). При желании можно воспользоваться и другими источниками -- об этом ниже.
#
# Для того, чтобы получить доступ к API прежде всего необходимо зарегистрироваться в Twitter в качестве разработчика и создать свое [приложение](https://apps.twitter.com/). После создания приложения будет доступен набор ключей, которые мы будем использовать для аутентификации. Эти ключи необходимо скопировать в соответствующие константы ниже. Подробнее о том, как работает аутентификация в Twitter API можно почитать [по ссылке](https://dev.twitter.com/oauth/application-only), хотя это нужно скорее для ознакомления: библиотека обращения с API позаботится о механизме аутентификации за нас.

# %%
CONSUMER_KEY = "0dtheZNlcjBemGJ6PLcIcM8eb"
CONSUMER_SECRET = "7icIh2jU7bwuDzmHr978wB2f3DpK2EEsioAypWKyRuiYGABdvg"

ACCESS_TOKEN_KEY = "781465906413273088-VeNI7oePGsLep2duwLpVOVkIaLTzS3L"
ACCESS_TOKEN_SECRET = "MEVsCOFnnOP6GMVeyfFfdci8cOFZx9n7efypAi87YFe9o"

api = twitter.Api(consumer_key=CONSUMER_KEY, 
                  consumer_secret=CONSUMER_SECRET, 
                  access_token_key=ACCESS_TOKEN_KEY, 
                  access_token_secret=ACCESS_TOKEN_SECRET)

# %% [markdown]
# Twitter API предоставляет информацию о местонахождении пользователя, но эта информация представлена в текстовом виде, например так:
# ```
# "location": "San Francisco, CA"
# ```
# Такие текстовый описания не слишком удобны для анализа, поэтому наша цель -- получить более структурированную информацию, такую как географические координаты, страна, город и т.д. Для этого удобно использовать геоинформационный сервис, например [GeoNames](http://www.geonames.org/export/web-services.html). Для его использования также необходимо зарегистрироваться, подтвердить регистрацию и включить поддержку API. После этого можно будет посылать запросы для нахождения нужной информации. Например на запрос
# ```
# http://api.geonames.org/search?q="San Francisco, CA"&maxRows=10&username=demo
# ```
# возвращается результат,
# ```javascript
# {
#     "totalResultsCount": 2112,
#     "geonames": [
#         {
#             "countryId": "6252001",
#             "adminCode1": "CA",
#             "countryName": "United States",
#             "fclName": "city, village,...",
#             "countryCode": "US",
#             "lng": "-122.41942",
#             "fcodeName": "seat of a second-order administrative division",
#             "toponymName": "San Francisco",
#             "fcl": "P",
#             "name": "San Francisco",
#             "fcode": "PPLA2",
#             "geonameId": 5391959,
#             "lat": "37.77493",
#             "adminName1": "California",
#             "population": 805235
#         },
#         {
#             "countryId": "6252001",
#             "adminCode1": "CA",
#             "countryName": "United States",
#             "fclName": "spot, building, farm",
#             "countryCode": "US",
#             "lng": "-122.3758",
#             "fcodeName": "airport",
#             "toponymName": "San Francisco International Airport",
#             "fcl": "S",
#             "name": "San Francisco International Airport",
#             "fcode": "AIRP",
#             "geonameId": 5391989,
#             "lat": "37.61882",
#             "adminName1": "California",
#             "population": 0
#         }
#     ]
# }
# ```
# из которого легко извлечь нужную информацию.
#
# **Замечание: для запросов необходимо использовать своего пользователя, кроме того количество запросов ограничено 30тыс в день**.
#
# Первым делом нам понадобится функция, которая возвращает информацию о местоположении для данного текстового запроса. Требуется реализовать функцию get_coordinates_by_location, принимающую на вход строку с местоположением и возвращает кортеж вида (долгота, широта, город).

# %%
GEO_USER_NAME = "dpreer"
history = {}
#r = requests.get('https://api.github.com/user', auth=('user', 'pass'))
def get_coordinates_by_location(location): 
    if location in history:
        return history[location]
    
    try:
        url = 'http://api.geonames.org/search?q="{}"&maxRows=1&username=dpreer'.format(location)
    except:
        #url = 'http://api.geonames.org/search?q="{}"&maxRows=1&username=dpreer'.format(location)
        print location, "symbolError"
        return (0.0, 0.0, "FAKE")
    
    par = {'type':'json'}
    r = requests.get(url, par)
    req = r.json()
    if not 'totalResultsCount' in req:
        print location, "accoutError"
        return (0.0, 0.0, "FAKE")
    if(req['totalResultsCount'] > 0):
        a = req["geonames"][0]
        if 'lat' in a and 'lng' in a:
            if 'countryName' in a:
                history[location] = (float(a['lat']), float(a['lng']), a['countryName'])
            else:
                history[location] = (float(a['lat']), float(a['lng']), "None")
                print location, "countryNameError"
        
        return history[location]
    print location, "locationError"
    return (0.0, 0.0, "FAKE")
    """
    This function gets geographic coordinates and city name
    form external web service GeoNames using 'location' string.
    
    NOTE: the returned value is FAKE. It's only used to show
    NOTE: correct output format.
    """
    # your code here

#d = {"type":'json'}
#r = requests.get('http://api.geonames.org/search?q="San Francisco, CA"&maxRows=1&username=dpreer', d)

# %% [markdown]
# Следующий шаг -- вызов Twitter API для сбора данных и сохранения их в data frame. После чего data frame c собранными данными совмещается с data frame, содержащим данные исходной обучающей выборки.
#
# В этой части задания нужно реализовать функцию `get_user_records`, которая принимает на вход прочитанный из файла `data frame` и возвращает список словарей, каждый из которых представляет данные одного пользователя. Для того, чтобы получить из объекта класса [`User`](https://github.com/bear/python-twitter/blob/master/twitter/user.py) словарь в правильном формате, нужно использовать функцию `twitter_user_to_dataframe_record` (4 балла).
#
# Так как скрипт работает существенное время, будем сохранять промежуточный результат.

# %%
ts_parser = lambda date_str: dateutil.parser.parse(date_str) if pd.notnull(date_str) else None

user = 0
user_records = []
tmp_file_name = 'tmp_user_records'
if os.path.exists(tmp_file_name):
    with open(tmp_file_name) as f:
        for line in f:
            user += 1
            try:
                user_records.append(json.loads(line))
            except:
                continue

processed_users = set()
for r in user_records:
    processed_users.add(r['uid'])
    
f = open(tmp_file_name, 'a')
        
def twitter_user_to_dataframe_record(user):
    dt = ts_parser(user.created_at)
    record = {
        "uid": user.id,
        "name": user.name,
        "screen_name": user.screen_name,        
        "created_at": dt.strftime("%Y-%m") if dt else dt,        
        "followers_count": user.followers_count,
        "friends_count": user.friends_count,
        "statuses_count": user.statuses_count,
        "favourites_count": user.favourites_count,
        "listed_count": user.listed_count,
        "verified": user.verified
    }
    
    if user.description is not None and user.description.strip() != "":
        record["description"] = user.description
        
    if user.location is not None and user.location.strip() != "":
        record["location"] = user.location
        record["lat"], record["lon"], record["country"] = get_coordinates_by_location(user.location)
    
    return record

f.close()
def get_user_records(df):
    users = []
    last_user = 0
    print "df:", len(df)
    for i in xrange(user, len(df), 100):
        if i % 500 == 0 and i != 0:
            f = open(tmp_file_name, 'a')
            f.write(json.dumps(users[i - 500:i]))
            f.close()
            print i
        buf = list(df['uid'][i:i + min(100, len(df) - i)])
        r = api.UsersLookup(buf)
        for j in r:
            users.append(twitter_user_to_dataframe_record(j))
    
    j = i
    while j % 500 != 0:
        j += 1
        
    f = open(tmp_file_name, 'a')
    f.write(json.dumps(users[j - 500:i]))
    f.close()
    return users
    # your code here
    # some_downloaded_user = get_user_from_api
    # also write user as json line in temporary file
    # return [twitter_user_to_dataframe_record(some_downloaded_user)]
    pass

# Maximum number of user IDs returned by Twitter's user lookup
user_records = get_user_records(df_users)
        
print "Creating data frame from loaded data"
df_records = pd.DataFrame(user_records, columns=["uid", "name", "screen_name", "description", "verified", "location", "lat", "lon", "country", "created_at", "followers_count", "friends_count", "statuses_count", "favourites_count", "listed_count"])
print "Merging data frame with the training set"
df_full = pd.merge(df_users, df_records, on="uid", how="left")
print "Finished building data frame"
# Out:
# df: 11947
# Marvel. DC.  locationError
# God is my refuge; gem❤️ symbolError
# Rock of Eternity locationError
# Palookaville, Iron City locationError
# layout by kconedits@tumblr locationError
# The Shire, A.K.A. PEI locationError
# The Fortress Of Solitude locationError
# 910-fayetteville locationError
# on your left locationError
# german/english tweets locationError
# Where The Food Is.  locationError
# you  don't  need to know  locationError
# multifandom locationError
# Limoeiro do Norte,Ceará,Brasil symbolError
# Suburbs of Philadelphia, PA locationError
# The South, darlin'! locationError
# NotEvenOnTheMap, CT locationError
# The Comfort Zone locationError
# 32.739805,-97.407933 locationError
# the savage land locationError
# kahradeleveen locationError
# Earth countryNameError
# Fish Stew Pizza, Beach City locationError
# INTP-T | he/him locationError
# TESD Town locationError
# where I'm at  locationError
# Skyrim locationError
# onision notice me locationError
# snapchat: iammel_2  locationError
# Washington, DC | Boston locationError
# Kedah | IIUM locationError
# Disneyland & Concerts countryNameError
# Gamerblogtv.com  locationError
# Lost in the series of tubes.  locationError
# layout by izzi! locationError
# © evankart | tumblr symbolError
# MN countryNameError
# takin pics locationError
# Amman, Hashemite Kingdom of Jordan locationError
# they/them locationError
# Silver Spring, MD (almost DC) locationError
# Mirkwood // Ancrath locationError
# Stalingrad/Rapture locationError
# Incógnito symbolError
# Seychelles wannabe. locationError
# In NYC, with Carmen San Diego  locationError
# Norcal Hell, USA  locationError
# California ✈️ Colorado symbolError
# Dancing With Monsters  locationError
# A short walk from Bywater locationError
# Nashville and Tampa  locationError
# raphael hamato locationError
# she/her locationError
# Storybrooke locationError
# my diet dr kelp locationError
# @STEELMOX for wrestling locationError
# Dirty Jerz locationError
# Youtube Land locationError
# 53 Queen St, Melbourne, AU locationError
# GREAT Britain. locationError
# Californee locationError
# Trouble Town Texas locationError
# KotoHonoUmi YouChika Haven locationError
# yonkers, ny but now in cali locationError
# Where I fucking live bitch locationError
# IPHONE 6 - IOS 9.3.5 OOH YEAH  locationError
# Dry CA thnx to Moonbeam locationError
# Where you least expect me locationError
# Jumping universes locationError
# For A Weekend Or A Lifetime locationError
# ° Classified File ° symbolError
# she|wlw|blm|layout: izzi locationError
# MARVEL, DC, OTH, CPD locationError
# NewMexico locationError
# D13. City of Oil locationError
# YouTube locationError
# Ann Arbor, MI/Orange, CA locationError
# The Best Coast, CA locationError
# Disneyland  countryNameError
# Comic Land locationError
# 2nd door on the left.  locationError
# OMNICRON PERSIEYE 8 locationError
# Parts Unknown locationError
# Arkham #Polla accoutError
# somewhere being annoying locationError
# READ THE RULES BEFORE SENDING  locationError
# she/they locationError
# Sin Bin 2.0 locationError
# SA countryNameError
# travis kirst tina ayah coral locationError
# Santa Barbara ✈ PDX symbolError
# https://www.amazon.com/gp/aw/ls/?ie=UTF8&lid=19RR5742YTPN5 locationError
# Chimichanga locationError
# bucky barnes enthusiast locationError
# on twitter. duh locationError
# The Halls of Justice locationError
# {comics/tv/film} locationError
# The goes trio xx locationError
# ✶✶✶✶ symbolError
# Depends on the place locationError
# Melboune Australia locationError
# Palm Springs/ Coachella Valley locationError
# Subterrainia locationError
# Alpha Quadrant locationError
# batcave in the upside down locationError
# I zoned out... locationError
# Chicago. Sometimes Hogwarts. locationError
# Moçambique/Maputo symbolError
# gauri owns this ass locationError
# JKT-IDN locationError
# TARDIS parked somewhere in NJ locationError
# new york (mostly) locationError
# ㅤㅤㅤㅤ symbolError
# leticia ♡ symbolError
# Around a Table locationError
# star wars voltron dc locationError
# Den currently in Wales locationError
# eiren | 21 | virginia locationError
# H.l - the slums  locationError
# farawayville locationError
# Underworld , Auradon locationError
# canada • she/her  • #BLM symbolError
# brunei's largest closet locationError
# 에프엑스°탑독°케힙합 (+girlgroups) symbolError
# Secret Science City locationError
# Bomb City, Oklahoma locationError
# probably lost in a damn forest locationError
# Poland / Łódź symbolError
# home all day locationError
# New Jersey - and proud! locationError
# DCEU locationError
# In a Galaxy Far, Far Away locationError
# Cybertron • Ba Sing Se symbolError
# AW GINGE! locationError
# ❝    ❞ symbolError
# 221B Baker Street locationError
# Tokyo, Japan 「東京都目黒区」 symbolError
# DC ✈️ NawfEast symbolError
# Instagram : nanimshahbudin locationError
# Stream Chats / The Database locationError
# Rockin out all over the place. locationError
# Flavor Town locationError
# they/them locationError
# IRC channel locationError
# #Zarry accoutError
# H-Town ✈ ACO ✈️ Dublin  symbolError
# Millennium Falcon locationError
# ÜT: 37.67995,-122.0907 symbolError
# christen press owns my ass locationError
# Another side of Moon  locationError
# 901 TN locationError
# ❄️ symbolError
# Assgard (rimshot, please) locationError
# Follow req okie locationError
# A dark corner of YouTube locationError
# Los Angeles☀️ symbolError
# Global / Manchester locationError
# oxfords, not brogues. ☆ symbolError
# See you at the hot tub! locationError
# Hogwarts locationError
# she/her locationError
# महाराष्ट्र, भारत symbolError
# In Your Heart All Along locationError
# The internet, silly!!! locationError
# Austin, Texas Baby!! locationError
# ATX !!!!!! Hook'em  locationError
# PUR | icon by: @IKNOWTHATROAD locationError
# SAWS-BERRY locationError
# In the stixs of Otter Lake, MI locationError
# Gotham City locationError
# was @nataliaromanovs locationError
# poopland locationError
# m.h + v.m + h.s ; ut locationError
# KwaNdongaziyaduma locationError
# Suva, Fiji Islands locationError
# OTRAMNL//032215 locationError
# Knowhere, Brazil locationError
# #BLM (She/Her)  accoutError
# from the  boondocks  locationError
# mind palace locationError
# Aztlán symbolError
# crying because of sam locationError
# Not in Nashville, TN locationError
# FS E PVD locationError
# CN Tower, Midgard locationError
# usually New England locationError
# Perth, West Aus locationError
# ally , ATL , she/her, leo locationError
# Here ✌️ symbolError
# The Phantom Zone, boo. locationError
# Lagos, Nigeria / Lee Temple locationError
# Slytherin House/Gotham/Wakanda locationError
# Quor'toth locationError
# blüdhaven symbolError
# East Jesus Nowhere locationError
# 3rd Marine Force Base, Okinawa locationError
# sodium chloride locationError
# Sarlacc Pit locationError
# Bᴏɴᴇs·s ♡ Lᴜʀᴇs ᴘᴇɴɢʏ™ symbolError
# they/them locationError
# she/they • bi • int. feminist symbolError
# Gallifrey locationError
# Target, seriously.  locationError
# Don't look at the Reel..... locationError
# Parts Unknown locationError
# ♦ ɴʏ/ʙᴏsᴛᴏɴ/ᴘᴀʀɪs ♦  symbolError
# Pacific NW locationError
# München, Deutschland symbolError
# Higher Melf Deck locationError
# ѕєєкιиg тнє αℓ¢нємιѕт ૐ symbolError
# Cydonia Valley, Mars (Utah) locationError
# new jersey on earth-982 locationError
# instagram-@tret2p locationError
# 1808 Danforth Ave locationError
# The Discworld locationError
# Yo mama's ass. locationError
# SoCal locationError
# I am where I am locationError
# over the horizon, kicking ass locationError
# les amis de l'abc • team red symbolError
# The Night Is Yours ☽ symbolError
# poppunk and marvel/dc trash locationError
# somewhere in the corn fields locationError
# a cocoon // she/her  locationError
# One, Derland locationError
# South Side, Bitch! locationError
# Galador, Golden Galaxy locationError
# lots of trans headcanons locationError
# my name's yasmin locationError
# facebook.com/TheHaterNation locationError
# your dad locationError
# iPhone: 52.080062,4.388943 locationError
# Somewhere in the galaxy.  locationError
# Guernsey, United Kingdom locationError
# NW LDN locationError
# #1 lana parrilla stan  accoutError
# chicagooo locationError
# Glasgow/Newcastle locationError
# TimeSplitter Street locationError
# Surrey, England (he/him) locationError
# Slytherin locationError
# Torreón, Coahuila symbolError
# In bed with Anders locationError
# protect glenn rhee locationError
# harleyivy is canon locationError
# Planet Earth (for now) locationError
# Home, Soon to return...! locationError
# multifandom™ symbolError
# Mega-City One locationError
# SLC, Utah that 8oh1 locationError
# ace lesbian she/her 19 british locationError
# London, ON/Port Huron, MI locationError
# Canaduh locationError
# NY/NJ locationError
# Baltic countryNameError
# they/them locationError
# Sydney • GOLF DADDY HARRISON™ symbolError
# (REDACTED) locationError
# Halfway out of the dark locationError
# บ้าน symbolError
# Elysium, Nirvana  locationError
# ashley is my best fren ⚡️ symbolError
# U.N.C.L.E locationError
# please read link! locationError
# Gotham City locationError
# dc comics  locationError
# ny | no not nyc you fucktard locationError
# across the road from K'un-lun  locationError
# chesie locationError
# Macapá, Brasil symbolError
# the middle of nowhere, canada locationError
# Disneyland countryNameError
# nerdypoc@gmail.com locationError
# Beasti Boys land locationError
# Rainapriyanka's heart locationError
# but where am I REALLY from locationError
# White Cis Male Scum locationError
# Marvel Lovers Fumb locationError
# TRANSLIVESMATTER locationError
# just a small unnamed moon  locationError
# Strategic Scientific Reserve locationError
# Europe countryNameError
# Near Philadelphia locationError
# Chance followed 9/5/16 locationError
# ÜT: 40.746549,-73.974806 symbolError
# London•Hollywood Los Angeles•  symbolError
# DM to buy Pixel Art $1.00 USD locationError
# ÜT: -26.169365,28.051313 symbolError
# ドーナツ屋さん symbolError
# Maryland (Parts Unknown) locationError
# she/her/hers locationError
# Slytherin, Hogwarts locationError
# playing game's locationError
# The 852 locationError
# Philadelphia, PA/La Jolla, CA locationError
# Planet Earth locationError
# artist | any pronouns !  locationError
# she/her locationError
# Ijk, United States Of Thrissur locationError
# thg t100 friends mcu+  locationError
# Stillorgan, Co. Dublin locationError
# Strathroy Ont. locationError
# The Cosmic Spaceways locationError
# Team Mystic locationError
# House Of Blue Leaves locationError
# bottom robert fanclub locationError
# ||NY|| locationError
# ÜT: 40.70787,-74.01289 symbolError
# she/her, bi | multifandom locationError
# Proverbs 4:23 | † | symbolError
# Land of Leprechauns | Mars locationError
# io sono ovunque io sogno locationError
# canada | vine: heximoff edits locationError
# BADOIT locationError
# HD 96064 locationError
# Lawton OK USA God Awful Town locationError
# Runnin thru the 6 with my woes locationError
# Divided States of America  locationError
# Parts Unknown locationError
# Philadelphia Area NJ, PA, NY locationError
# Eastcote   Pinner locationError
# she/her locationError
# fereldan locationError
# The BatCave locationError
# 日本 symbolError
# 128.199.218.220 locationError
# Trollhättan, Sweden symbolError
# San Fransokyo  locationError
# Apartheidbosch  locationError
# thg dc marvel locationError
# Planet Zebes locationError
# youtube cheeetah man juntao locationError
# Hustle Flow Nation HQ locationError
# A City Wit No Hoes locationError
# ÜT: 44.765819,-63.669379 symbolError
# Fuck you don't worry about it  locationError
# Where Holtzmann sends ghosts. locationError
# On your left locationError
# Satellite of Love, Scotland locationError
# team mystic locationError
# ID countryNameError
# 3.250751,101.701172 locationError
# RP|MC|AU|18+|DCEU|Bi locationError
# Gotham NY/Corvallis OR locationError
# getting drunk & taking drugs locationError
# Suplex City, Bitch locationError
# galaxy, searching for dreams  locationError
# The SuperHero Satellite: Space locationError
# I'm be where I be  locationError
# Rocketites HQ locationError
# James Andrew McAvoy locationError
# Area XVI locationError
# Dublin/Foster City CA locationError
# earth 65  locationError
# Detroit-ish locationError
# @chadwickhalse locationError
# the highlight factory, ga locationError
# Assumption | 2018 locationError
# almost nashville locationError
# Tally ☀️ symbolError
# World countryNameError
# The Filthy T locationError
# gotham city locationError
# new york city ha i wish :( locationError
# Belle River, PEI locationError
# idk/idek as pronouns cause idk locationError
# Yorkshire and The Humber locationError
# Panem District 5 locationError
# Bay Area, NYC, LA, London locationError
# nowhere, #DOGGOD, New Earth. accoutError
# In ur Internets locationError
# Multiverse locationError
# treehouse of horror locationError
# NYC/HWOOD/PARIS/MADRID locationError
# Northeastern California locationError
# Gotham City locationError
# nibiru locationError
# The Midwest, baby! locationError
# Kicking monster arse locationError
# anstari locationError
# by the tv with my beanie low locationError
# Fourside locationError
# home with sebastian stan locationError
# Binary system, mostly 0s. locationError
# #PandaTink accoutError
# Middle Finger - Heart locationError
# Aokigahara locationError
# N 39°6' 0'' / W 123°13' 0'' symbolError
# Dan Nicky your Bobbie s locationError
# pyroland locationError
# 18 | he/him locationError
# Slytherin Pride ϟ symbolError
# Delaware (where else?) locationError
#   u are going have 2 asksheild locationError
# Zootopia locationError
# Falmouth/London/Hoth locationError
# multifandom locationError
# i'm not really here locationError
# Secret Lair locationError
# Pune, Bengaluru, Goa, Mumbai locationError
# #BlackLivesMatter accoutError
# Oau,ile-ife locationError
# bumfuck, nowhere locationError
# 2 blocks from the river :D locationError
# Roswell-Whitney-Lubbock  locationError
# The Interwebs locationError
# Somewhere in NJ.  locationError
# EAST VILLAGE, NYC locationError
# Realm of dilligaf locationError
# k18ay locationError
# Canadia locationError
# 221b Baker Street locationError
# Chicagoland area locationError
# she/her | bi | marvel locationError
# JKT-YK,Indonesia locationError
# slytherin || canada locationError
# SD  LV  locationError
# U.S.A. Florida locationError
# 1d/star wars/marvel/etc. :-) locationError
# Car Window Tinted locationError
# Inside my imagination locationError
# 1° 16′ 0″ S,36° 48′ 0″ E symbolError
# Twitter Earth locationError
# #MarvCollege | #MoxieRose accoutError
# Hollyweird. locationError
# Sweet Lady Kisses locationError
# ÜT: 6.51792,3.35156 symbolError
# Pixel artist Skin maker locationError
# In a place between realms... locationError
# ÜT: 37.421009,-119.63913 symbolError
# kingin' wit ventuh. locationError
# Australium locationError
# 17, feminist, pansexual locationError
# Balls deep in your asshole locationError
# DCEU/MCU locationError
# ¼ souvenirs: artemis' arrow symbolError
# Nanda Parbat via Virginia, USA locationError
# bottomless pit, awful abyss locationError
# Sector 2814 locationError
# ??? locationError
# Darkest Cambridgeshire . locationError
# tony stark  locationError
# GETTING OUT OUR DREAMS locationError
# ÜT: 39.104601,-77.528893 symbolError
# Wherever Redditors want us. locationError
# feminist • she/her symbolError
# 日本 関東地方 symbolError
# Woodysmovietalk.wordpress.com locationError
# LOS ANGELES 2029A.D. locationError
# so far up seb's ass locationError
# Transylvania (KLIA) locationError
# Somewhere Around You locationError
# 9.25.15 ♡ symbolError
# multifandom locationError
# ig whitch / whitchcraftcosplay locationError
# BLACK LIVES MATTER locationError
# Fassy protection squad locationError
# erebor, middle-earth locationError
# #626 Los Angeles, California  accoutError
# IG- Fecerex locationError
# YVR |ArellanoCommaa@gmail.com  locationError
# arrow/dc locationError
# Zihautenejo locationError
# London, Beds and Herts locationError
# miss peregrine's time loop locationError
# home sleeping locationError
# CA ☼ symbolError
# wherever they serve chx nugs locationError
# Classified locationError
# God is #1 accoutError
# Digital Purgatory locationError
# reddit.com/r/RyanDunbrack locationError
# WHO CARES?!!!! locationError
# Just over there. *points* locationError
# Multiverso52 locationError
# newb right on locationError
# Black Sweden  locationError
# US countryNameError
# Avengers Tower locationError
# In Your DMs locationError
# I'ma be where I'm at!  locationError
# dc marvel #FreePalestine accoutError
# Where only the truth is told. locationError
# McKinney, TX headin' to LA locationError
# 24 / 09 / 16 locationError
# Toronto/Ethiopia locationError
# [|RP|Hybrid|Claimed|Luke|] locationError
# i love zoe vaughn locationError
# Parts Unknown locationError
# #BlackLivesMatter accoutError
# Brinstar locationError
# Just north of Amishland, OH locationError
# Honeymoon ãve. symbolError
# planet unknown locationError
# belly of the beast amerikkka locationError
# she/her locationError
# probably crying over OTPs locationError
# yikes locationError
# The Upside Down. Gallifrey locationError
# Digbeth, Birmingham, UK locationError
# 92:48 locationError
# LAX-PDX-SEA locationError
# Secret Rebel Base, CA (L.A.) locationError
# NYC / LA locationError
# #blacklivesmatter accoutError
# New World, The Far West locationError
# #SavageHeroine accoutError
# Next to the pickles locationError
# 《Married to♡@NeroTheNight》 symbolError
# bi | she/her | APA  locationError
# Spacebound locationError
# yaless| herls is my watson✨ symbolError
# Columbus, OH ||| Atlanta, GA  locationError
# Dungeon Family Forever locationError
# europe countryNameError
# @FiraHepburn locationError
# Belfast, Norn Iron.  locationError
# 10880 Malibu Point, 90265  locationError
# canoodling with chris evans locationError
# iTunes, Stitcher, TuneIn, etc. locationError
# Near SF locationError
# NYC Bay*Bee locationError
# Up at the Big House locationError
# In the box on the table locationError
# elle hay alex locationError
# for anton locationError
# Never Neverland locationError
# A galaxy far, far away locationError
# Always stalking Joschua locationError
# In Outer Space. FL locationError
# je suis au canada bitches locationError
# Winterfell locationError
# Hell (AKA South Dakota) locationError
# #RP accoutError
# Detroit suburbs  locationError
# @NYCC TableU14 locationError
# 127.0.0.1 locationError
# NNID: boettam locationError
# she/her; #blacklivesmatter  accoutError
# New York/Stars Hollow locationError
# ❤️CHRIST...ALWAYS AND 4/EVr❤️ symbolError
# ig - milan.dandwani locationError
# Moscow-London-Paris locationError
# DC | Star Trek | Voltron locationError
# ÜT: -6.123052,106.838091 symbolError
# The Emerald Isle  locationError
# In the workshop locationError
# Walton Lah locationError
# derp vill canada locationError
# the 'burbs of NYC locationError
# Roaming the halls tweeting¥¥¥× symbolError
# Hackney, London. 0208 985 1141 locationError
# Road of Sacrifices, Florida locationError
# jay | they/them locationError
# facebook.com/vintagephilly.pa locationError
# NC countryNameError
# e pluribus anus locationError
# marvel|dc|starwars|mr.robot locationError
# In your closet locationError
# São Paulo, Brasil symbolError
# Planet Vegeta locationError
# Twilight Forest locationError
# Нижний Новгород symbolError
# kris sab maddie hunt locationError
# iPhone: 53.217098,-2.882452 locationError
# Somewhereinamerica locationError
# Somewhere close but far locationError
# The Basement locationError
# in my own head too much locationError
# MN by way of IL locationError
# almost always gone locationError
# Frenchies™ symbolError
# Wish I knew locationError
# On Your Left locationError
# 40.752509,-73.996066 locationError
# LA • NYC • JERSUALEM • TLV symbolError
# Mumbai/Bhopal/Oxford  locationError
# between the nones of march locationError
# A large pile of blankets locationError
# FSociety locationError
# he/him ✩ 21 ✩ catrachx symbolError
# Beach Goth V locationError
# she/her locationError
# The Milky Way Galaxy locationError
# In The Garden Of England, UK locationError
# Making Magic W/ Amora         locationError
# Черноярский район, Россия symbolError
# Yennefer's ass locationError
# My Basement locationError
# The Fylde Coast, UK locationError
# Royal Palace of Atlantis locationError
# Misery, Missouri  locationError
# Near Philly, PA, Bitch!  locationError
# A Higher Dimension  locationError
# St. Elsewhere locationError
# 5W.NPT.RI.US locationError
# Hidden Leaf Village locationError
# Corner of Clark and Kent locationError
# Near a keyboard locationError
# The Fantastic Fortress locationError
# yeah i'm EMO who fucking cares locationError
# NOW: LA / THEN: The 6 locationError
# grant's fancy pants™ symbolError
# London~South of the river Styx locationError
# Chicago Incorporated locationError
# Surulere / D[M]V locationError
# Stars Hollow, CT locationError
# Meereen locationError
# ♥in your wildest dreams symbolError
# Kaiemdor, Azeroth locationError
# hala madrid |-/ locationError
# Stately Classick Manor locationError
# Take time to be kind  locationError
# the void locationError
# Makeshift Prison in STAR Labs locationError
# Croydon, SE London locationError
# Vancouver (via Tatooine) locationError
# not on earth that's for sure locationError
# The Cupboard Under The Stairs locationError
# Montréal symbolError
# VV Cephei A locationError
# Uncharted Territories locationError
# panicing at the disco locationError
#  Hove, East Sussex BN3 7HG locationError
# Yucca Valley, CA (YVR-ite) locationError
# England UK / Lake Como (Italy) locationError
# Central City Picture News locationError
# dc sw marvel friends locationError
# drama || she/her locationError
# Theme Parks... and beyond. locationError
# Asteroid M, Earth orbit locationError
# lost in my brain  locationError
# Somewhere in the Argand plane locationError
# always with her no matter what locationError
# Earth 2 locationError
# I'm bad. I'm nationwide locationError
# #FreePalestine accoutError
# the Fury Road locationError
# Between Gotham and Gamma Base locationError
# On the battlefield. locationError
# Stuck on route 12, Kanto locationError
# Behind the mixing board locationError
# the suoip sloop locationError
# Account Run by Matt locationError
# Earth-9602 locationError
# ✯ Marvel. RP. MC. symbolError
# Podcastville, USA locationError
# Plastic Beach locationError
# ☾the queen of salt☽ symbolError
# The Johto Region locationError
# Raccoon City locationError
# d c k a | blacklivesmatter locationError
# Under MrBeasts Bed/Luna  locationError
#  Sebaholics™ symbolError
# jem carstairs stan locationError
# My House, Earth locationError
# Anywhere but Westeros locationError
# they/them  locationError
# Aldershot, Hapshire, UK locationError
# Chicagoland, U.S.A. locationError
# Pan she/her 17 rbb fatties™ symbolError
# canada /worldwide locationError
# kay/20/any pronouns/infp locationError
# #WaitOnItt  accoutError
# halloweentown locationError
# I need my girlfriend... locationError
# 10.74794°N, 122.5675°E symbolError
# Where The Wild Things Are locationError
# ( ͡° ͜ʖ ͡°) symbolError
# 20, Hull, England locationError
# Jupiter Fleet universe  locationError
# SoCal locationError
# ENTJ - World Traveler - 7 locationError
# tony stark defense squad locationError
# IL countryNameError
# Everywhere,Nowhere... locationError
# Westeros locationError
# Born-Nashville/Live-Bluegrass locationError
# SMOOVE MOVES   locationError
# Curitiba, Paraná, Brazil symbolError
# thighs of betrayal  locationError
# 9¾ symbolError
# 23 West Main Street Geneva, Oh locationError
# Felony Flats, PDX locationError
# @GuiseOfMoth's little girl.  locationError
# squam™/mia/mel/lou symbolError
# loud iambs (Louisiana) locationError
# iPhone: 13.100105,-59.602444 locationError
# she/her #BLM  accoutError
# zoe | she/her | the moon locationError
# Doomstadt, Latveria locationError
# ☆Wanderluster☆ symbolError
# ZouNation locationError
# Nowhereland locationError
# shitposting domain locationError
# #chrismin accoutError
# Barcelona/Worldwide locationError
# hong kong/london  locationError
# kamurocho locationError
# Storybrooke Maine locationError
# she:her locationError
# IN A CAVE WITH A BOX OF SCRAPS locationError
# Avengers Tower, Portland OR locationError
# The Batcave, USA locationError
# ~~no fave is unproblematic~~ locationError
# |-/ locationError
# サウスパーク symbolError
# Somewhere in Space. locationError
# ÜT: 38.304446,-104.610729 symbolError
# STUCKY  ⍟ symbolError
# #Koreatown Los Angeles, CA accoutError
# Earth-1218, Fandom Multiverse locationError
# SoCal - IEBG/Super Arcade locationError
# up Buckys ass locationError
# Send me a DM! I'm up past 11PM locationError
# a server locationError
# Manchester-Nairobi-Las Vegas locationError
# Londor  locationError
# xxi || infj || hufflepuff  locationError
# hiredhq 114 locationError
# Deep in the Heart of Texas locationError
# Stainless locationError
# Rockbottom place to be. locationError
# Orlando The land of milk and n locationError
# iPhone: 0.000000,0.000000 locationError
# Depreston locationError
# dying, texas locationError
# Texas,our Texas! locationError
# HMS Puffy Muffin locationError
# vapor enthusiast / emily locationError
# not where i wanna be ; she/her locationError
# somwhere with dogs and cats locationError
# marvel, sw, + locationError
# Earth (Hopefully) locationError
# Flavortown, USA locationError
# Wayne Enterprises, Gotham locationError
# Da South West Side locationError
# FROSTIRON locationError
# Castle of Lions, Space locationError
# Kalimdor,US locationError
# one of the flyover states locationError
#  anime • boybands • cats  symbolError
# Bahamas, New Jersey locationError
# カエルと一緒。 symbolError
# Gotham City locationError
# gaming | comics | tv shows locationError
# stl | she/her | 18 | b in lgbt locationError
# NC ✈️ ? symbolError
# he/him cis het locationError
# London, ON/Toronto/Hogwarts  locationError
# In a galaxy far, far away..... locationError
# 勇気百倍 symbolError
# ฉีหลิน วัลเล่ย์ symbolError
# takeitsløw symbolError
# Central PA with cows and corn locationError
# Where the hell am I? locationError
# 서울, 대한민국 symbolError
# Everything Is Listed locationError
#  Nap time w/ Danaaaaa  locationError
# The planet Wondor locationError
#  — 07/17 × 06/17 mlf • svt symbolError
# Sumaré/SP symbolError
# Bowerstone, Albion locationError
# alternate universe locationError
# That's Classified locationError
# for my tweeps ⤵ symbolError
# oceanside, ca., earth  locationError
# Gotham city  locationError
# canadia locationError
# Living w/@SweetLilVictim 4 now locationError
# Void Stepping locationError
# II,IV #ArtGang #TNTLKP #KC accoutError
# Yeah.......nope locationError
# snap: zaptiethebear locationError
# Tamriel locationError
# Mandalore locationError
# America countryNameError
# daphnei or none locationError
# mommyandbabyreviews@gmail.com locationError
# P H I L A D E L P H I A locationError
# lainate beach locationError
# Gotham city  locationError
# wherever you go.......  locationError
# The Time War locationError
# Catching me some Mortys locationError
# Indefinable locationError
# inac bc school locationError
# Toronto-GTA locationError
# The land of Charedon locationError
# 638 South St, Philadelphia locationError
# space or illinois maybe locationError
# Unkown locationError
# in a hammock locationError
# THE BATSY CAVE locationError
# CroydonNarniaLutonLagos locationError
# matt syd nimo locationError
# up seb's ass locationError
# © MyFilmClub 7th Dec 2015-2016 symbolError
# Where the Wild Things Are locationError
# a lil inactive bc of school locationError
# comics  star trek  star wars locationError
# Valley of the Wind locationError
# cali & hawaiʻi symbolError
#  she/her•intp  #BLM symbolError
# Gotham City locationError
# she/her locationError
# Rampageo Island locationError
# Arrowcave, Starling City  locationError
# Jakku w/ Rey, Burnside w/ Babs locationError
# Syracuse, N.Y. locationError
# ↓ My Music ↓ symbolError
# It depends locationError
# Decaying locationError
# Archanean Maverick Hunter HQ locationError
# tHe LaNd !  locationError
# ♑️ symbolError
# Gorgeous Prince George's Co MD locationError
# Yggdrasil locationError
# bcm.$ locationError
# — ⌗ᴘʜᴏᴇɴɪx / sv. symbolError
# Mulder's basement office.  locationError
# Melaka to Johor Bahru locationError
# hogwarts locationError
# gamma 102 locationError
# Demi | Nina | Margot | Daisy locationError
# Planet Earth--World Of Outlaws locationError
# dc tgd sh + locationError
# ALEXANDRIA safe zone locationError
# Parts Unknown locationError
# TWU20' locationError
# Kingdom of Kelogia and Gilumia locationError
# Gotham City, USA locationError
# On a cellphone. locationError
# Ba Sing Se locationError
# they/them locationError
# Perumnas 2 Karawaci, Tangerang locationError
# ash + su$ie/spacejesushoe 4/12 locationError
# Scaborough,Ontario locationError
# Tokyo → Manila → Wellington ✈ symbolError
# ✯ Marvel. RP. MC. symbolError
# beb♡ symbolError
# ohmyfassy is my wife ✧ symbolError
# The Danger Room, Canada locationError
# New York, Everywhere locationError
# Oregon/Minnesota, USA locationError
# Empire State University, NYC locationError
# fg fatima manda alex mar kylie locationError
# Instagram @ljb3510 locationError
# ★knoxville, tn  symbolError
# Makai the Demon Realm locationError
# Detroit...ish locationError
# West Coast? locationError
# AB/SK, Canada locationError
# With Me, Myself, and I locationError
# Away with the fairies locationError
# Home since I don't have a life locationError
# In the shadows locationError
# No countryNameError
# they/them or sometimes she/her locationError
# my computer locationError
# Peace of Mind  locationError
# Krisst's heart locationError
# piss off locationError
# Madison, WI | LV-426 locationError
# Another Dimension locationError
# VERY LESBIAN  locationError
# Can'-Ka No Rey locationError
# California 0/5 locationError
# Rhode Island ⚓  symbolError
# Stuck With Brownback  locationError
# Heart Attack & Vine locationError
# ThorkiWincestJ2DrarryHannigram locationError
# multifandom mess locationError
# Dimmitt/Canyon, TX locationError
# Snakeway locationError
# The Quiet Grave of Space locationError
# #DrawIsLife accoutError
# Jotünnheim symbolError
# columbia, sc via chicago, il locationError
# #MARVEL #FLARROW #LOT accoutError
# Frisco,Fillmoe(Harlem West) locationError
# iPhone: 39.379593,-76.776482 locationError
# champandchipsmgt@yahoo.com locationError
# earth 616 locationError
# she/her locationError
# Common Room locationError
# Brooklyn! locationError
# False Church, VA locationError
# party city locationError
# constantly lost in equestria locationError
# Snapchat: SupremeBootyGod locationError
# kathrengxdanilo locationError
# WORLD countryNameError
# NewJorkTity locationError
# iPhone: 55.885581,-3.485398 locationError
# Avengers Tower locationError
# Tadasu Forest, Titan; JPTR locationError
# Xbox GT: Z2FY locationError
# The World That Never Was locationError
# Reason for heart eyes.  — 0221 symbolError
# with my rose  locationError
# Off the charts! locationError
# Casa Bonitas locationError
# ᴹᴬᴿᵞᴸᴬᴺᴰ, ᵁˢᴬ symbolError
# in horto  locationError
# All over the world locationError
# multifandom locationError
# 914 - 718 locationError
# back in the bean bag locationError
# geekbrunchpodcast.com locationError
# México, Monterrey symbolError
# The Mouth of Madness locationError
# sad girls club locationError
# you sent for me locationError
# she/her | Vancouver, BC locationError
# WOOOOOOOOOOOOOOOO  locationError
# sophia:ari:julio:kevin:carlos locationError
# napping duh locationError
# Live from the 'couve locationError
# São Paulo symbolError
#  MY AIRSHIP UP IN ETHERSPHERE locationError
# ♔100314♔ symbolError
# Around the World locationError
# PSN: FaTaLxSlumerican locationError
# Stark Industries,Riverside, CA locationError
# Murdaland. locationError
# Somewhere South  locationError
# Somewhere in time locationError
# teddy marcy amy locationError
# Avengers Headquarters locationError
# Bigornia, Akkron locationError
# viva o girasol locationError
# Scotlandism locationError
# feminist ¯\_(ツ)_/¯ symbolError
#  Salisbury via Fortrose locationError
# #ShakyBird&QuickyBird accoutError
# hannah | bi | slytherin | aos locationError
# The 'Wood (Beachwood) locationError
# San Jose, CA aka OZ  locationError
# Facebook: TooBossy Rutherford locationError
# ℋ&ℒ ❀ ✩ ⭐ ➳♡ ∞ ≡  ✪ symbolError
# 97-14 Liberty ave OzonePark locationError
# Braavos locationError
# osomatsu-san hell  locationError
# On a Trip, Hueco Mundo locationError
# Crawling Skin, Lincoln Park  locationError
# SECRET WARRIORS HQ locationError
# Aloha, OR 97006 locationError
# Grand Theft Auto Vice City locationError
# Parts Unknown locationError
# All over the place locationError
# ships ruined my life locationError
# In a very sad sitcom locationError
# »¡Married!♡6.28.14«〖#Ꮓᴀʀᴀᴛʜᴏꜱ〗 symbolError
# Miami Beach, FL - Saipan, MP locationError
# lova is the aaron to my roy locationError
# arkham asylum  locationError
# Another plane of consciousness locationError
# slasher sluts™ symbolError
# Hoth tonton Street locationError
# tina arielle vaggies locationError
# thea » lu[bes] » beast daddy symbolError
# Parker Industries, Japan locationError
# she+her/they+them locationError
# Hogtown ❤ Wpg Head ☁️ Soul Fl  symbolError
# JHB,S Africa Repr3zenT  locationError
# glorious Sydney locationError
# 守る(^ー^)⛧ϟ✨(◕‿◕✿)☆三(≖ ◡ ≖✿) symbolError
# Massachussets locationError
# my ass locationError
# en mi casa :v locationError
# Southbank London  locationError
# middle of philly locationError
# 「мυlтιғandoм aт ♡」 symbolError
# A savanna near you locationError
# da getto  locationError
# ÜT: 39.0634294,-77.1240717 symbolError
# Our own rooms. locationError
# San Juan, Puerto Rico, USA locationError
# Chloe trash dumpster :) locationError
# The Darkside locationError
# tony. 23. bi. cis. he/his.  locationError
# ÜT: 6.594091,3.338214 symbolError
# Montréal, Québec symbolError
# Tyria  (Miami, Fl) locationError
# Savage Land but I travel too locationError
# bitch planet locationError
# RP/FL locationError
# she/her locationError
# (215) Dover Road locationError
# #BlackLivesMatter accoutError
# in a cave with a box of scraps locationError
# fighting evil by moonlight locationError
# 1234 World Radio locationError
# New Orleans/Los Angeles locationError
# IN countryNameError
# [mv|cнerιĸ|deѕcrιpтιve|18+] symbolError
# SO ILL locationError
# Wonderland/Hogwarts/TARDIS{PA} locationError
# bee ☆ 21 ☆ she / her symbolError
# Thailandอันเปลี่ยวร้างของสม็อก symbolError
# joancomics.etsy.com locationError
# Sokovia locationError
# Where you least expect it locationError
# Trapped in Hell locationError
# New Joisey locationError
# in the gym  locationError
# aka Hellcat locationError
# Gin-chan's balls locationError
# black lives matter locationError
# marvel trash ✨ symbolError
# (they/them) locationError
# Rodeløkka, Oslo symbolError
# ATL✈️MKE✈️ALIEF symbolError
# Des Moines,IA (DARKHAVEN) locationError
# SEHS locationError
# Rivendell/Mereen locationError
# Highgarden. locationError
# Mirkwood Forest  locationError
# Marvel Universe  locationError
# #blacklivesmatter accoutError
# berlin • sadly w/o dolly symbolError
# Bottom ✈️ Here symbolError
# the upside down locationError
# Philly, Delaware County Pa. locationError
# Heart is in Denver! locationError
# Among the Thoroughbreds locationError
# *✧･ﾟ:* ♡ *:･ﾟ✧*  symbolError
# Galaxy M-8724  locationError
# 323✈702 symbolError
# Miami, but born/bread Gotham  locationError
# Gotham City /SATX 210 locationError
# fangirling somewhere locationError
# In The Nexus locationError
# multifandom | she/her locationError
# icon by @kkamabr locationError
# dirty jerzey - Queens ny locationError
# rdj noticed 31 times :') locationError
# idk tbh locationError
# Transformers Universe locationError
# icon by nupao.tumblr.com ✨ symbolError
# USA its a country and a chant! locationError
# iPhone: 41.954830,-86.448944 locationError
# Somewhere in Neverland  locationError
# far away from the real word locationError
# California - Newyork locationError
# A$AP MOB  locationError
# l&h countryNameError
# Toronto Canada / Parts Unknown locationError
# letterboxd.com/marywinstead locationError
# cheys locationError
# L.A. all day locationError
# Worlds Far Away locationError
# Castellón symbolError
# São Paulo - Brazil symbolError
# Pacific Northwest countryNameError
# N 52°27' 0'' / W 1°49' 0'' symbolError
# Marvel Universe 1015 locationError
# Behind The Scene locationError
# http://lexacain.blogspot.com/ locationError
# L.A. ✈️ NYC ✈️ New Genesis symbolError
# a trash can in france locationError
# Cuddling with Lexie locationError
# 221B Baker Street, London locationError
# sirius • qsmv symbolError
# ÜT: 44.534766,-89.527531 symbolError
# Edge of Reality  locationError
# mezosoico  locationError
# Harbinger Foundation locationError
# Cybertron locationError
# Darkside of Eden locationError
# Phoenix, Tucson, Vegas locationError
# #ALLCAPSFAMILY accoutError
# Ghana || A Large Sofa, Florida locationError
# Ravenclaw | AKF locationError
# domowrites.blogspot.co.uk locationError
# São Paulo - Brazil symbolError
# [ ᔕᐯ - ᖇᑭ ] — #Мercy symbolError
# DC | she/her locationError
# pontiac mich  locationError
# Gotham City locationError
# Toronto/Los Angeles locationError
# Space of Reds locationError
# highdensitypolyeurethanefoam locationError
# Doing some geek shit locationError
# UWS. WAR. CWA. | Pseudo. locationError
# poTayto locationError
# films-books-tv-science locationError
# fl / ooc / fc: wheein locationError
# Bahrain, Planet Earth. locationError
# BEN'S HEART, HOGWARTS, 221B locationError
# he•they•she symbolError
# Dubai ♥ symbolError
# (she/her) locationError
# USS Enterprise NCC-1701-D locationError
# cabeswater locationError
# Happy place. Happy heart. ❤ symbolError
# Back in the Bay, Cali locationError
# GEG  PDX  ATL locationError
# Fairfield, CA 94534 locationError
# Fortress of Solitude locationError
# Virginia (where else?) locationError
# cloud19 locationError
# Gütersloh, Nordrhein-Westfalen symbolError
# Parts Unknown locationError
# Somewhere Awful locationError
# Africa countryNameError
# PH | sb  locationError
# Nyssara's love child locationError
# Camp Half-blood locationError
# Новосибирск symbolError
# 運命の島 symbolError
# 221B on Pigfarts (England) locationError
# Gallifrey near Apokolips locationError
# braindripping.wordpress.com/ locationError
# Planet Paradise locationError
# First star on your left (WA) locationError
# St Louis and Arkansas  locationError
# Unzervalt, Laniakea locationError
# The shadow realm  locationError
# Everywhere and nowhere locationError
# Blighty!  locationError
# 1/33 of Army of Lesbians™ symbolError
# Lost Scandalous, CA locationError
# Anywhere But Here locationError
# tean titans locationError
# Your Bucky locationError
# voltron hell locationError
# oxford, via canadia locationError
# forever @ Natalia village  locationError
# meme team ★ 한솔 ★ he/him symbolError
# she/her locationError
# theTOPshelf locationError
# madeline ● ● joselyn symbolError
# comics • movies • photography symbolError
# https://curiouscat.me/micahhxx locationError
# eye of agamotto ❂ symbolError
# bi, she/her  locationError
# in my lane locationError
# Xavier's School for GY locationError
# Naija Is too Soft to leave locationError
# On a Cross-Canada Road Trip locationError
# crunch time 1/1 locationError
# PhanTrashNumberOne locationError
# hogwarts locationError
# Jørpeland symbolError
# clone club locationError
# |-/ locationError
# RIP Travis Nunes  locationError
# kinga kelly sam spela locationError
# Spain/Los Ángeles/Canadá symbolError
# they/them locationError
# Brighton London Glasgow UK locationError
# 'be brave. be braven.' - L.M locationError
# Blackwood Pines   locationError
# CYBēRSPāCE  symbolError
# Mansion In The Sea locationError
# Isla Nublar! locationError
# shaяing musical imageяy symbolError
# Plant Intelligence Project locationError
# viva las vegas locationError
# 221B Baker Street • Ivalice symbolError
# Its not easy being green locationError
# Portland-ish, OR locationError
# The Other Charleston locationError
# Our News, Our Voices locationError
# ÜT: 52.286235,-1.526588 symbolError
# the upside down locationError
# some fictional place I guess locationError
# snap: barcwllos locationError
# The Real Enchanted Forest locationError
# #Bɪᴏᴄʜᴇᴍɪsᴛ  symbolError
# Bangkok, 태국 symbolError
# Killing Walkers w/ the baes. locationError
# MI~California~Colorado~Utah~NV locationError
# The Savage Land..ANCIENT Kemet locationError
# home/CAC locationError
# Chicago | SCAD | she/her/they locationError
# USA! USA! USA! locationError
# Chicago, Illionis locationError
# USA - presently theMD/DC Metro locationError
# Jakarta Capital Region, Indone locationError
#  אֲרַ֥ם נַֽהֲרַ֖יִם | Denmark symbolError
# land of kilts locationError
# somewhere being detained locationError
# @minusgasm locationError
# Photo Shopping locationError
# Thanks For Visit locationError
# comics • sw • cherik  symbolError
# overthrowing your cistem locationError
# 13.11.15 UK// locationError
# A dweller on the threshold locationError
# virginian living in colorado locationError
# Trotsville, rural East Yorks locationError
# be ryan to my tom locationError
# Cloverfield Lake locationError
# vinnland and the 505. locationError
# #Songoftheday  accoutError
# Autobot City, Earth locationError
# Dublin/Offaly locationError
# Chile - She/her - queer af  locationError
# Over here and over there  locationError
# money vault locationError
# Sootopolis City locationError
# The #Batcave in #GOTHAM accoutError
# The DMV...Chocolate City...DC locationError
# Los Angeles, NYC, and RVA locationError
# Temporarily: San Antonio, TX locationError
# ~Toronto Someday~ locationError
# The Avengers Tower in Gotham locationError
# in a lab, doing cumistry locationError
# the night court locationError
# WorldWide 80Million StealthRUs locationError
#  B.R.O.O.K.L.Y.N  locationError
# she/her \\ bi as hell locationError
# Lost Scandalous, CA locationError
# District 13, Panem locationError
# they/them & ae/aer locationError
# Avengers Tower, Baker Street locationError
# Watching Chelsea Handler locationError
# Marvel, DC, 1D, stucky who? + locationError
# ღ gracie ღ symbolError
#  December 16, 1991 locationError
# Forever Docked Ashore locationError
# there's no x-man in x-men locationError
# MD✈LA symbolError
# Our Fair City (USA) locationError
# ทวีตเยอะมากรำคาณเชิญอันฟอล symbolError
# Rogue One locationError
# » @SkittlesLayouts symbolError
# so far up sebastian's ass  locationError
# Multifandom™ symbolError
# Middle of Nowhere locationError
# Somewhere in the Multiverse locationError
# Multi-dimensional locationError
# IG: mileswaitforitarnold  locationError
# The room where it happens. locationError
# Locash locationError
# 510 / 805 locationError
# Hovering above a comics page locationError
# space-time bound  locationError
# Guaynabo City locationError
# Galactic Sector ZZ9 Plural Z  locationError
# Look under your bed locationError
# Downtown Passaic New jersery locationError
# Cairo || Kuwait City locationError
# SoCal locationError
# Winterfell locationError
# cw european premiere apr 2016 locationError
# Always in Florida locationError
# Dothan, AL| Huntsville, AL  locationError
# #BLACKLIVESMATTER accoutError
# I live in Carlisle, PA, USA locationError
# Theatre of Dreams locationError
# Bucky's backpack locationError
#  Jas ❤ ||leo|| seacon2017 symbolError
# good ol' Central Cal locationError
# © varia13 symbolError
# In a place less crowded locationError
# You are they? What do we want? locationError
# Straight Outta Brampton  locationError
# Montréal, Québec symbolError
# fejiLandz locationError
# FHS CHORUS locationError
# New Attilan  locationError
# Star City || #ChilledWriter accoutError
# mcalisters deli tea urn locationError
# On the web locationError
# Playstation Network locationError
# 5 meters away from do kyungsoo locationError
# In a galaxy far, far away... locationError
# Earth 616 locationError
# So Flo locationError
# On The Bright Side locationError
# norway (she/her) locationError
# cvans sstan evanp pmore marvel locationError
# N 5°35' 0'' / W 0°10' 0'' symbolError
# the black beverly hills locationError
# Hinterestland locationError
# they/them locationError
# On The Road Again locationError
# 31°25'S  152°25'E symbolError
# BBDS™ Ace Aces™ symbolError
# multi-fandom  locationError
# Watchpoint: Gibraltar locationError
# Fghj locationError
# Scattered to the winds locationError
# LosAngeles, CA locationError
# The mines of Moria locationError
# Instagram @gorditoe locationError
# platform 9 3/4 locationError
# Mom City. locationError
# Bowels of Wattpad, DeviantArt locationError
# 9 Locations in the US locationError
# VT/NH, Upper Valley locationError
# 42, Wallaby Way Sydney locationError
# Minneapolis / TwinCities / MN locationError
# tøp symbolError
# Челябинск symbolError
# Royal Priors Leamington Spa locationError
# Somewhere on Planet Earth. locationError
# Chicago-ish locationError
# probably writing locationError
# SC  countryNameError
# The Land of Enchantment locationError
# Ondobe | Windhoek | Ohalushu locationError
# deez nuts ha funny joke locationError
# Kepler-186f, Kepler-452b locationError
# Bogotá symbolError
# NUKA WOOOOOOOOOOOORLD!!! locationError
# she / her locationError
# stan got7 locationError
# Prob. buried in a book #again accoutError
# diana, zara // south africa  locationError
# México symbolError
# Seat 3A on the mental plane locationError
# ℓσѕ αиgєℓєѕ symbolError
# Hyrule locationError
# WCTA 2017 locationError
# Potadeia locationError
# All over the map. locationError
# O-H-I-O!!  locationError
# Dublin, Dublin City (53.338086 locationError
# marvel + dc locationError
# The Mushroom Kingdom  locationError
# ÜT: 33.033631,-117.076578 symbolError
# ↓Watch My New Video↓ symbolError
# Paper towns locationError
# Cincinnati ✈️ Bay Area symbolError
# Coast to Coast baby... locationError
# NJ + NY locationError
# Venangoland, PA locationError
# 20, swe locationError
# twd | spn | marvel | dc | hp locationError
# avengers station locationError
# Latveria locationError
# Location: PH (Patini's Heart) locationError
# University of Malaya locationError
# CCJKMOT locationError
# Larryville, KS locationError
# Temecula, CA➡️ Tempe, AZ symbolError
# Deep Jungle of Hawaii locationError
# The Irish Times locationError
# Denver, CO, USA; 22 yrs old locationError
# #BlackLivesMatter accoutError
# night vale locationError
# HOLY SHIT, I dunno! (FL) locationError
# A secret bunker in Lancaster locationError
# Brooklyn Centre Cleveland locationError
# pixieland locationError
# Purwakarta, JaBar, Indonesia locationError
# true idol hell locationError
# 21; he/they locationError
# Gotham City and Singapore locationError
# The 3rd stone from the Sun locationError
# marvel.dc.arrow.tvd.sh.ouat. locationError
# ph · multifandom symbolError
# Breaking Peach's Mugs locationError
# they/them + she/her locationError
# they/them • amab nb symbolError
# ï¿½T: -6.216317,106.830734 symbolError
# iPhone: 0.000000,0.000000 locationError
# He-him Ing/It/Fr/Es.  locationError
# she/her / comics / hamilton locationError
# All around the Tri-Cities  locationError
# hogwarts locationError
# The Twilight Zone locationError
# Multiverse (or, singapore) locationError
# valar dohaeris locationError
# was cheekysugg locationError
# A liminal state locationError
# @mzblackcanary 's Babs locationError
# GLOBAL! locationError
# The Grand Line locationError
# In your heart ;) locationError
# Miramoe Media Group locationError
# 623, Az locationError
# 106.1FM/1340AM WTAN RADIO  locationError
# weasleys' wizard wheezes locationError
# FLEE GOD DJ'S locationError
# My Thoughts locationError
# ∠( ᐛ 」∠)_ symbolError
# Straight Outta Grim's Toy Show locationError
# Most likely at Avengers tower locationError
# Cybertron born Greyskull bred. locationError
# [[SV RP 21+]]  locationError
# 3hunnit Block ⛽ symbolError
# The Cinémathèque Française symbolError
# Middle of Nowhere, Va locationError
# brklyn ny locationError
# somewhere hallucinating locationError
# Nįgęŗįā  symbolError
# ÜT: 32.0050122,-90.9569727 symbolError
# ny / any pronouns / blm locationError
# Metro Atlanta, GA (suburbia!)  locationError
# parts unknown locationError
# The Marvel Universe locationError
# USA! USA! USA! locationError
# Vector By Way Of Florida. locationError
# Shahadah's ❤ symbolError
# chaura nic jas locationError
# Santiago Bernabéu Stadium symbolError
# minnah • 17 • she/her symbolError
# StrawberrySwing On VioletHill locationError
# West Virginia (where else?) locationError
# Path of the Righteous Man  locationError
# #FloridaMan accoutError
# ﹫ʀɪᴅᴅʟᴇɪsᴍ's ❬ Kɪɴɢ ᴏғ ɢᴏᴛʜᴀᴍ. symbolError
# a comic book store locationError
# SC : corinesal  locationError
# Projected Universally locationError
# ʝƙԳԾρՏʝԹԳɧƙȝԾʅρԳƙՏԺʝԳԲ symbolError
# Bengaluru/Palakkad locationError
# Vol. 2, Issue 5, page 25 locationError
# ZZ9 Plural Z Alpha locationError
# #tKAllDay #EatIt  accoutError
# Essos locationError
# Hogwarts • Panem • Gotham City symbolError
# 20-he/ve-megane enthusiast locationError
# 東京 (Tokyo) symbolError
# [REDACTED] locationError
# 9 high street Tooting  Broadway  SW17 0SN locationError
# ♡ symbolError
# Planet Earth locationError
# Ꮹᴏᴛʜᴀᴍ Ꮯɪᴛʏ [Ꮰᴏᴋᴇʀ]  ┇#Ꭱᴋɪɴɢ┇ symbolError
# Thedas locationError
# Terra, Sol System, Orion's Arm locationError
# Tom - 19 - he/him they/them locationError
# Online! locationError
# Charlottetown PEI Canada locationError
# CA, USA countryNameError
# in yo dumpster locationError
# Arundel, South England locationError
# Winnipeg!! locationError
# Discouraged locationError
# | Muscat, Oman | lahore, pak  locationError
# Kait ❤️ symbolError
# slytherin dorm locationError
# Vasaria locationError
# consumed by schoolwork locationError
# Damn right, Texas! locationError
# blackbun locationError
# Lost Trying To Find My Way locationError
# Erm...London locationError
# South East Of Somewhere locationError
# shondaland locationError
# Generation Of Modern Daytime.  locationError
# psn:claireyeah locationError
# vrkhclsd locationError
# south london. she/her. locationError
# A galaxy far far away locationError
# 0629CYW♡ symbolError
# Available on iTunes locationError
# 9¾ symbolError
# somewhere in your house  locationError
# Ayala Ave, Makati City locationError
# วอแว symbolError
# ...
# near Munich, Germany locationError
# Yonkers, NY - CT locationError
# All over the world! locationError
# Part timer  locationError
# London. New York. Halesowen. locationError
# weareallconnected locationError
# in the lou... STL locationError
# In a galaxy of discoball stars locationError
# Only follow normal people. locationError
# DC✈️Santa Fe✈️Intergalactic symbolError
# New York in my house! locationError
# Gallifrey locationError
# (they/them) locationError
# Whorelando locationError
# Naked Game Network locationError
# ÜT: 40.923427,-73.813327 symbolError
# bre maya  locationError
# Linkingshire locationError
# tatinof atlanta locationError
# Islington mostly locationError
# Montréal symbolError
# └A + ✈ WORLD-WIDE ✈ symbolError
# Snapchat: itsmedylanray locationError
# The Motorcity locationError
# Right behind you!  locationError
# Self-Pity locationError
# bnha◇lovelive◇sbr◇rwby◇FE symbolError
# #BotSwin469 accoutError
# I'm at  ████ symbolError
# somewhere between home & lyon locationError
# Digbeth, Birmingham, UK locationError
# Punpunia locationError
# Classified locationError
# Nowhere near a Cracker Barrel locationError
# tomorrowland locationError
# the Force knows where... locationError
# IN THE JUNGLE OF AFREEKA locationError
# melanie|she/her locationError
# Doomstadt, Latveria locationError
# Somewhere in Australia locationError
# The 13th Dimension locationError
#  Isle of Sheppey, Kent locationError
# Avalor locationError
# Space Sector 2814 locationError
# the gay part of hell locationError
# 214 ✈️✈️✈️ 850 symbolError
# beaconhills #teamthor accoutError
# Got Chimichangas? I'm there. locationError
# JAX, FLA  locationError
# marvel dc st sw hannibal got  locationError
# Back in Mississippi locationError
# The USSA locationError
# the safeway sandwich station locationError
# 哈利 symbolError
# Loth Angeleeth via Detroit locationError
# Trantor, First Galactic Empire locationError
# JHB-PRLS locationError
# (she/her) • sgc symbolError
# G A R D E N A , C A  locationError
# Nightosphere locationError
# #FaZeup  accoutError
# The Emerald City, Oregon locationError
# Up in the Sky locationError
# i have many moms and dads locationError
# Secret lair. Or my office. locationError
# Movies, Comics, and your heart locationError
# @EvieFleisherr locationError
# A galaxy far far away.... locationError
# Harvest/Huntsville , Alabama locationError
# ⛅️    symbolError
# My Phone, My Ipad, and My Mind locationError
# Morrison's Doom Patrol locationError
# Planet Earth locationError
# the City of Shadows locationError
# /dev/zero locationError
# Interstellar locationError
# The TARDIS  locationError
# Okaga, CA locationError
# Ultralight Beam  locationError
# Between your legs :O locationError
# #ProtectTransLives accoutError
# THE DMV!!!!!! locationError
# Tumblr locationError
# Bra Gibb's Smokolo locationError
# emma , she / they. locationError
# Crawling to the moon locationError
# 1/2 bro twins locationError
# Donate: https://goo.gl/8ix70G locationError
# http://dogbl0g.wordpress.com/ locationError
# multifandom & sb trash locationError
# TitleTown, Massachusetts locationError
# Stark Tower, NY locationError
# Near the Hellmouth locationError
# In the depths of my mind. locationError
# Rapture, MY city locationError
# Hlatseng, South Africa locationError
# Will Co.-ish, Il locationError
# USA • 22 symbolError
# Docking Bay 94 locationError
# star wars rat™ symbolError
# ÜT: 33.853139,-117.91738 symbolError
# In de bioscoop locationError
# BabySitting RDJ  locationError
# 401 / 518 / 404 locationError
# Hogwarts locationError
# @EmWatson knickers  locationError
# Earth-1218 locationError
# الكويت symbolError
# Oakland ➡️ LA ➡️ Oakland symbolError
# Current home- Orlando, FL locationError
# At the Airports ✈️ symbolError
# 0v0 Paradise  locationError
# kat ❁ colorado symbolError
# San Frantastic locationError
# ☼/never symbolError
# Plot 1130 On The Interwebs locationError
# High Wycombe, U.K. locationError
# #DMV Based accoutError
# •they.them• symbolError
# James Callahan locationError
# Idahoe locationError
# coming to eat your brains locationError
# UGANDA 'Place To Be' #UGDrone accoutError
# Fortress of Solitude locationError
# Watching you... locationError
# Brookland, Jonesboro,AR locationError
# Wayne Enterprises, Gotham City locationError
# she/her locationError
# Halloween Town locationError
# FALCONS 2-1 COLTS 1-2 UGA 3-2 locationError
# up in the air locationError
# On Your Left. locationError
# gypsy ✈ NYC, BOM, LAX symbolError
# 53.796081,-1.75493 locationError
# Flexin in Zamunda locationError
# The Thomcave locationError
# Greater Toronto Area Realtor locationError
# Winterfell locationError
# Bandung and Jakarta  locationError
# behind y-OH GOD LOOK OUT locationError
# Bye bye WDW hello Tn Smokies locationError
# Village Hidden in the Leaves locationError
# Metal Inc. locationError
# iamtherightone1@gmail.com locationError
# Somewhere over the rainbow locationError
# Not Here locationError
# 3.4 billion light years east locationError
# Hearts and minds  locationError
# Existential Crisis locationError
# SoCal locationError
# Indianapolis for now locationError
# Tranent  THE BIG T locationError
# agloe  locationError
# she/her locationError
# home is where the ❤️ is symbolError
# galaxy far far away locationError
# Красная Kомната (The Red Room) symbolError
# Oakland/SF * NYC * LA locationError
# artwork of icon is not mine  locationError
# Gagalangin, Tondo Manila locationError
# Hollywood Goodfella blog locationError
# saving the tigers locationError
# Yonkers, NY, CT, NJ, ATL, LA  locationError
# Ice Planet 2002 locationError
# Hufflepuff | ENFJ | Wampus  locationError
# Somewhere around nothing locationError
# #QueerAndStillHere accoutError
# your fridge locationError
# Dynamic Adventures locationError
# Mechanist Lair locationError
# Shitpost City locationError
# Hollywood ✈ New York ✈️ London symbolError
# Near Philadelphia, PA locationError
# Wherever locationError
# Zenn-la, Mars' (Galle Crater) locationError
# UNDER YOUR BLANKET ♥  symbolError
# chugiak-eugene locationError
# Not bloody hawaii  locationError
# ÜT: -6.192963,106.935807 symbolError
# UK (With worldwide shipping!) locationError
# • any pronouns • symbolError
# NY by way of Houston locationError
# Get a Warrant locationError
# #SteinBaraka accoutError
# he got on my elevator 8/17/16 locationError
# Gotham City locationError
# Where I belong locationError
# zuko || korra locationError
# Satan's Armpit locationError
# in a galaxy far far away locationError
# Serenity Still Flying locationError
# #blacklivesmatter accoutError
# So. California, land of sun locationError
# Earth-616 locationError
# sector C-137  locationError
# location: driver's seat locationError
# kuwj™ symbolError
# icon by @TheSunWatcher locationError
# Sigma Kappa WKU locationError
# reverbnation.com/mikeschmidt4 locationError
# We are everywhere. locationError
# 21 | she/her locationError
# Venta Belgarum locationError
# tv • hp • asoiaf • am • books  symbolError
# thepinksmoke.com locationError
# It's Just Banter locationError
# Slytherin locationError
# synonymsofcomplicated | Tumblr locationError
# Your heart...  locationError
# 220 2nd St. East,Whitefish, MT locationError
# Fortress of Solitude, WV locationError
# way too many fandoms locationError
# Within consciousness locationError
# Essex U.K England locationError
# Philadlephia, PA locationError
# Okinawan Martial Arts Center  locationError
# wordlwide locationError
# Chandler, AZ, USA (Earth 616) locationError
# living n Coimbatore / India locationError
# English Tea Stain  locationError
# Futuristic City, 2688 locationError
# Northern Ca countryNameError
# Antioch, IL ➡️ Dubuque, IA symbolError
# Lost in the supermarket locationError
# life; fucken' bittersweet life locationError
# New York/Madripoor/Japan/L.A.  locationError
# The Fields of Justice locationError
# ZZ9 Plural Z Alpha locationError
# marvel | dc | voltron | misc  locationError
# Alola Coast locationError
# Bucky Barnes' Stasis Chamber locationError
# Chitti Nagar, Vijayawada locationError
# Somewhere I belong to  locationError
#  Editor | YouTuber | VFX locationError
# they/them locationError
# facedown on the floor  locationError
# Allysha ♡ symbolError
# The bad boy hangout locationError
# dream in new orleans ⚜ symbolError
# Republic of Yucatan locationError
# Somewhere in Africa locationError
# Isle of Misfit Toys locationError
# They/Them|Genderqueer(afab)|UK locationError
# ~ NZ ~ locationError
# Multiverse locationError
# 9 high street Tooting SW17 0NS locationError
# Im Outside locationError
# 3.1390° N, 101.6869° E symbolError
# Daly City - Union City locationError
# aelbein@gmail.com locationError
# My Comfort Place  locationError
# ᴴᴱ/ᴴᴵᴹ symbolError
# National Teen Magazine locationError
# Online & On-Campus #ProEdPride accoutError
# Miami--St.Thomas--NYC--Germany locationError
# Ptown, Oregon locationError
# Sun Devil Nation locationError
# In Formation locationError
# Wales, baby! locationError
# Super World/Detroit/LA/Krypton locationError
# #OUN #Xr4Eve accoutError
# Arkham Asylum locationError
# From that U.S.A  locationError
# Georgia, Murica locationError
# Classified Base, AZ locationError
# ph  countryNameError
# The Speedforce locationError
# SN 1998 BW locationError
# marvel, dc, and bands  locationError
# Planet button locationError
# Bellingham, WA / The Internet locationError
# 19, she/her, pan locationError
# Los Angeles, CA - 1984 locationError
# Maintaining AerSuperiority™ symbolError
# Second Union HQ locationError
# iTunes, TuneIn Radio, Stitcher locationError
# #BlackLivesMatter  accoutError
# Winchestertonfieldville, IA locationError
# the swamps of savannah locationError
# earth countryNameError
# Great White North, Eh? locationError
# Phoenix, Arizona U.S.A. locationError
# {she/her} locationError
# Chronically positive. locationError
# Duval ✈ Memphis  symbolError
# Somewhere in Georgia locationError
# Sunny (mostly) California locationError
# EHS 2017 locationError
# all gaming relms locationError
# DMV-The M To Be Exact locationError
# Montréal, Québec symbolError
# married to @daddymalia locationError
# marvel•dc•dw•sw•spn•thg symbolError
# From:London Live:Devon,England locationError
# The DMV  locationError
# Newbridge Heights locationError
# Buisness19O  locationError
# [Chi]lligan's Island locationError
# 1007 Mountain Drive, Gotham locationError
# Riverside, SoCal locationError
# Nowhere near the dog park locationError
# Does it matter? locationError
# upstate Ohio locationError
# Clocktower ❤️  symbolError
# Near-apex of the U.S. heart   locationError
# Garage Island-TN locationError
# The deepest level of hell locationError
# ☁️ symbolError
# i'm a stevebucky™  symbolError
# marvel dc x-men got fannibal locationError
# Parts Unknown locationError
# #BLACKLIVESMATTER -slytherclaw accoutError
# Outlaw Queen locationError
# Scooter — Writer symbolError
# Northwest Ohio via Central NJ locationError
# Zenn-La locationError
# Mostly the Forest of Dean, locationError
# 10 Cloverfield Lane, NY locationError
# on the run with Loki locationError
# Garden Grove, Califronia  locationError
# KoHoStreet.com locationError
# My local Comic Shop locationError
# saturn's junk yard locationError
# The Nothing Farm locationError
# Cthulhu Regio locationError
# ÜT: 41.977783,-87.690925 symbolError
# The 6 (oh three) locationError
# p164-168 at: locationError
# United States Meme Corps locationError
# Michigan Badlands locationError
# there for you locationError
# Екатеринбург symbolError
# Everywhere, Disneyland locationError
# outside Philly locationError
# Snyder, ZA locationError
# Hogwarts locationError
# #blacklivesmatter she/her infp accoutError
# mx countryNameError
# Donations gladly accepted locationError
# Pinkckneyville, Il locationError
# Slo-Hio  locationError
# they/them she/her locationError
# Suburban London locationError
# in a room, not sleeping locationError
# between Asgard and Gallifrey locationError
# Guadalajara, México symbolError
# Wherever I'm needed locationError
# NJ/NY locationError
# NSFW locationError
# HoChiMinh.VietNam symbolError
# Northern Lordaeron locationError
# Somewhere in Ohio, US locationError
# [Marvel RP] locationError
# Yorkshire and The Humber locationError
# Sunnydale High locationError
# Miami | Florida locationError
# Hollywoo locationError
# Snapchat:YeetTheLegend locationError
# โตแล้วจะแรดที่ไหนก็ได้ symbolError
# LAAAANDEN locationError
# All Possible Universes locationError
# Planet of Sound locationError
# gryffindor locationError
# Probably by the food locationError
# rwby hell locationError
# Coco Bread & Sofrito. locationError
# Mewni locationError
# parts unkown  locationError
# FOLLOWS YOU everywhere you go locationError
# Bundaris locationError
# ignore all tweets before 2016 locationError
# All over locationError
# Out Here locationError
# Popular Culture locationError
# Illinois, but also the UK? locationError
# 신화컴퍼니 symbolError
# comics • movies • TvShows symbolError
# MOVIES!MUSIC!GIMME! locationError
# Trenzalore, New York  locationError
# USS Enterprise (NCC-1701) locationError
# 51.538879,-0.051759 locationError
# New York, Portland, LA locationError
# gay lit™ symbolError
# 177A Bleecker Street locationError
# End of the world to your town  locationError
# Thedas locationError
# Probably With My Girlfriend locationError
# ✨I bleed bees. Probably. ✨  symbolError
# Living in NJ/Working in NYC locationError
# Interested in GREAT people! locationError
# iPhone: 34.227627,-119.182358 locationError
# ÜT: 37.038078,-76.391967 symbolError
# snapchat: davidhakub95 locationError
# Sierra foothills of California locationError
# SOR MnG wd Dalty 5/28 & 8/2 locationError
# Pitulandia, FL locationError
# UK but it should be The USA locationError
# Boxtel, the Netherlands locationError
# In a love-hate relationship with Marvel studio locationError
# Free 24 hour chatroom locationError
# 3349 N. Halsted, Chicago locationError
# MD countryNameError
# Brampton, Ont. Canada locationError
# 32 Carisbrooke Road WS10 OJA locationError
# Gotham City locationError
# bellarke trash locationError
# @teaeyang locationError
# INGLXWXXD ︻╦╤─ ¯\_(ツ)_/¯ symbolError
# alicia vikander locationError
# Coming for you locationError
# Snapchat: SincerelyLeahh locationError
# Санкт-Петербург symbolError
# tay jenna locationError
# The Void locationError
# UTD (UT of Ducks) locationError
# NYC / PA locationError
# The Fortress of Funk locationError
# Kalos Region moving to Alola  locationError
# tenterden or a sodding airport locationError
# love your life and work hard locationError
# In my own little world. locationError
# ÜT: 37.612933,-77.445971 symbolError
# Also tweet'g as @HeLeftNoTrace locationError
# Google Map™ symbolError
# multifandom locationError
# female / aquarius locationError
# Seattle, Wa / Manchester, NH locationError
# CA MI FL locationError
# a key click away locationError
# (NB) they locationError
# Robinnest locationError
# Ohio #CedarWoman #ParrotCare accoutError
# the void locationError
# Dealership, Arizona locationError
# lebanon✈️italy symbolError
# Themyscira locationError
# Finding Neverland.... locationError
# Roanoke VA...also Middle Earth locationError
# Nowhere special... locationError
# possibly hell locationError
# W i n d y  C i t y ⛅ symbolError
# Fandom Caribbean locationError
# Genosha locationError
# Con @anachoink y #Villa accoutError
# Skyrim, Tamriel locationError
# The REAL world locationError
# A TOY BOX NEAR YOU! locationError
# NYC #LeftHandedWriter accoutError
# on the road to glory locationError
# 45.415175,12.369255 locationError
# #BlackLivesMatter accoutError
# #221 Baker St., London accoutError
# Blackburn - HORRORSHOW - ????? locationError
# Not sure where I am... locationError
# icon: tedkorrd on tumblr locationError
# Atlantis, Ocean countryNameError
# Planet of the Bathing Apes locationError
# Cair Paravel, Narnia locationError
# enfj / ravenclaw ✨ symbolError
# insta - jelocastillo locationError
# Somewhere near Narina locationError
#   ☄ Schwarzenegger Allee 007 ☄ symbolError
# Xbox GT: atomicfart67 locationError
# Gotham City locationError
# Bogor, Jakarta, Newcastle locationError
# NYC and San Francisco locationError
# Livin for the Weekend locationError
# Planet Earth Bruh  locationError
# Ames and Des Moines, Iowa locationError
# north countryNameError
# wherethewildthingsare locationError
# दुआ में याद रखना (कोटा , भारत) symbolError
# The frozen north locationError
# The Jovian System locationError
# ᴄʀᴏᴄᴏᴅɪʟᴇ ɪsʟᴇ symbolError
# Ελλάς symbolError
# If i knew i would tell you locationError
# In my Studio working.  locationError
# In Glamourous California  locationError
# Ass Cheek Valley locationError
# Creating data frame from loaded data
# Merging data frame with the training set
# Finished building data frame

# %%
#f = open("save", "w")
df_full
# Out:
#                       uid  cls                  name      screen_name  \
# 0               202388889  1.0                   NaN              NaN
# 1              1392518336  0.0          Tomboy Tarts      TomboyTarts
# 2               361208576  1.0         THE MANC GEEK         BigA85GL
# 3              1535215357  1.0                 L 🎃 🍂      laurynjiles
# 4              4396196375  1.0     #1stEdifyToUplift    EdifyToUplift
# 5                17938477  1.0       Skelly & Mulder  SkellyScribbles
# 6      720288026681716737  1.0           Zane Savage     SiNGLEGADGET
# 7               174004739  1.0          marc 👹👽👻👻👾👾💀     _MightyMarc_
# 8                53783678  1.0          Lady Attis ⚦        ladyattis
# 9               257662370  1.0  Nick Watches Marvel!   NickWatchesMCU
# 10             4795355113  1.0   Superman Cap Marvel   KryptonsWizard
# 11             1633971270  1.0              Van Goth    PikeFishing16
# 12             2803810119  1.0              Ragnarok       Vanguard90
# 13             2244770588  1.0        EssenceCartoon   EssenceCartoon
# 14              102071251  1.0         Dwight Fidler           Kersus
# 15             3358825450  0.0                  Jess     Deadlybarnes
# 16              555940842  1.0          ((((HERE))))     eIectroheart
# 17             2469354073  0.0        Niche Magazine  NicheMagazineUK
# 18              360464656  0.0        Princess Megan     Laneperson13
# 19               77243076  1.0      Ronelo S. Ladiao     RoneloLadiao
# 20             1731752761  1.0                K33G3N      keegykuehne
# 21             2330149164  0.0                     -      SherliHydra
# 22             2830586398  1.0    Michael T. Johnson  BasicsSuperhero
# 23              443273019  0.0      Matthew Glowacki      nofriends52
# 24             2591381383  0.0     Big Ideas Machine  Bigideasmachine
# 25             1093716612  1.0       Mercedes Conway  AfricasExplorer
# 26               36620392  1.0         Kervyn Cloete    TheKervynator
# 27             3437626995  1.0               Richiee  rickie_rushmore
# 28              387962514  1.0        Andrew Johnson  WrestlingAndrew
# 29             2938363689  1.0          Swagga_Kings      KingsSwagga
# ...                   ...  ...                   ...              ...
# 11917          1551606846  NaN               Dave N.         Dave3Dln
# 11918          2515843570  NaN             Sզմìէէer.    NiftyArachnid
# 11919          3177164330  NaN      Rodrick Long Jr.     ProLionGamer
# 11920  738922093463634000  NaN                   NaN              NaN
# 11921            30783602  NaN          b2rian lopez           b2rian
# 11922            23043649  NaN       christine smith  131christine131
# 11923           370117168  NaN        Team Marketing      Team2Market
# 11924           121233392  NaN              10/18 ♎️     AdRianneAdGe
# 11925          3794670447  NaN      Latestcanada.com     latestcanada
# 11926           634578158  NaN             panorina🎨        grizislay
# 11927          1063049935  NaN              Mr-O-Dot          okemawo
# 11928           553917747  NaN            Dave Dixon       Shockdingo
# 11929           628400126  NaN     Bottled Lightning  BottleLightning
# 11930          2450565163  NaN          James Gavsie      JamesGavsie
# 11931            16569278  NaN  CTVMorningLiveOttawa   CTVOttMornLive
# 11932          1944969114  NaN             King Trey    PettyKingTrey
# 11933            77377177  NaN       KP Kev the Poet       kevthepoet
# 11934          4343171772  NaN          TotalOutplay     totaloutplay
# 11935            33929806  NaN              Han Solo  _TheLastAvenger
# 11936           505986984  NaN              Couchman   Comfy_Couchman
# 11937            15585700  NaN           Kirk Manley         batmankm
# 11938  755055152613233000  NaN                   NaN              NaN
# 11939            38068469  NaN              MGiraldi         MGiraldi
# 11940            26628289  NaN                 Isaac         ibot2000
# 11941           249975867  NaN               Rebecca      LiteraryBex
# 11942          3741233607  NaN           Great-Stuff       Splurgehub
# 11943  750807944871240000  NaN                   NaN              NaN
# 11944          2818242018  NaN             Tokerware  Tokerwaredotcom
# 11945          2263956151  NaN         Té Nickerson💩   nickerson_taye
# 11946           133581466  NaN          Kayna Storey       lovelyKayn
#
#                                              description verified  \
# 0                                                    NaN      NaN
# 1      Celebrating the classic tomboy spirit with a b...    False
# 2      Mancunian geek, blogger/writer/reviewer. Consu...    False
# 3      I'll be waiting here for you on this New York ...    False
# 4      Awareness.Advocacy.Ascend🎈• Building awareness...    False
# 5               visual artist, writer, and photographer.    False
# 6      Current gadgets, tech news and reviews, in a s...    False
# 7                                                    NaN    False
# 8      Your friendly neighborhood androgynous android...    False
# 9      Excelsior #TrueBelievers❗️#MCU‼️ #LukeCage 9/3...    False
# 10     The Twitter feed for Superman & Captain Marvel...    False
# 11     I don’t hate your friends. I’m just not intere...    False
# 12                                                   NaN    False
# 13     We make funny cartoons on YouTube. PLEASE SUBS...    False
# 14     Tabletop gamer, theologian, tv watcher, and sm...    False
# 15                                   but he's my friend,    False
# 16     hi im raya!! and i tweet nonsense im sorry | b...    False
# 17                                                   NaN    False
# 18     20yo Canadian cis chick, armchair activist, I ...    False
# 19     I'm back to twitter and it's been a long long ...    False
# 20                  i'm a regular on the tweeter-totter🗣    False
# 21                              I'm a bundle of sadness.    False
# 22     Just a fan of Superheroes trying to get my nam...    False
# 23     Destination still unknown. Let's pray we stay ...    False
# 24     We're a London-based B2B Technology PR & Marke...    False
# 25     Photographer, musician, makeup enthusiast, and...    False
# 26                        Follow me if you want to live.    False
# 27                                Time 4 SUMTHING Stupid    False
# 28     A Lonely Pirate that drifted away from his Mat...    False
# 29     I'm a cool person to get along with. I like me...    False
# ...                                                  ...      ...
# 11917                                                NaN    False
# 11918  ↱『ᴇᴠᴇʀʏʙᴏᴅʏ's ғᴀᴠᴏᴜʀɪᴛᴇ sʜᴏᴇ ᴡᴇᴀʀɪɴɢ sᴘɪᴅᴇʀ. ᴘ...    False
# 11919                                                NaN    False
# 11920                                                NaN      NaN
# 11921  i draw pictures and tweet nonsense. follow for...    False
# 11922  I care about all things! #environmental  #Anim...    False
# 11923  We are Team 2 Marketing. Marketing. Social Med...    False
# 11924                  SC: Adrianneadge IG: Adrianneadge    False
# 11925  https://t.co/cz1EEBMr8X is a news aggregator, ...    False
# 11926                                                NaN    False
# 11927                                               True    False
# 11928  #VoiceActor for Kito (TheJourneyDown) Blop (Du...    False
# 11929  Imagination engine and storytelling studio fou...    False
# 11930  #ExecutiveProducer, #Author, #MMA & #BJJ Instr...    False
# 11931  Official account of CTV Morning Live - Ottawa'...     True
# 11932  I speak my mind frequently. No one can replace...    False
# 11933  The Hip-Hop Bard, poet, MC, singer, sax player...    False
# 11934                       Gameplays or Plays on Games.    False
# 11935                         Life is the biggest troll.    False
# 11936  Most comfortable of all superheroes! Also a re...    False
# 11937  Illustrator, Comic book artist, designer and c...    False
# 11938                                                NaN      NaN
# 11939  An Eagles/Bulls/Blackhawks/White Sox fan. I co...    False
# 11940  Comics. Movies. Music. Good Old Fashioned Love...    False
# 11941  A Writer and a Reader writing about what she r...    False
# 11942                                                NaN    False
# 11943                                                NaN      NaN
# 11944  making something great, be patient.... #Tokerw...    False
# 11945  A little about me: I enjoy long walks on the b...    False
# 11946                                                NaN    False
#
#                           location       lat        lon               country  \
# 0                              NaN       NaN        NaN                   NaN
# 1              Singapore/Malaysia    1.54860  103.52690              Malaysia
# 2                   Manchester, UK  53.48095   -2.23743        United Kingdom
# 3                     Marvel. DC.    0.00000    0.00000                  FAKE
# 4          God is my refuge; gem❤️   0.00000    0.00000                  FAKE
# 5                     Richmond, VA  37.55376  -77.46026         United States
# 6                 Toronto, Ontario  43.70011  -79.41630                Canada
# 7                              NaN       NaN        NaN                   NaN
# 8                  Minneapolis, MN  44.97997  -93.26384         United States
# 9                      Seattle, WA  47.60621 -122.33207         United States
# 10                Rock of Eternity   0.00000    0.00000                  FAKE
# 11                             NaN       NaN        NaN                   NaN
# 12                             NaN       NaN        NaN                   NaN
# 13                       Ohio, USA  39.96118  -82.99879         United States
# 14         Palookaville, Iron City   0.00000    0.00000                  FAKE
# 15                             NaN       NaN        NaN                   NaN
# 16      layout by kconedits@tumblr   0.00000    0.00000                  FAKE
# 17                             NaN       NaN        NaN                   NaN
# 18           The Shire, A.K.A. PEI   0.00000    0.00000                  FAKE
# 19        Iloilo City, Philippines  10.69694  122.56444           Philippines
# 20                             NaN       NaN        NaN                   NaN
# 21                         Area 51   2.96667   35.51667                 Kenya
# 22                     Oakdale, MN  44.96302  -92.96494         United States
# 23                  Cleveland Ohio  41.49950  -81.69541         United States
# 24            City of London, Bank  51.51407   -0.08843        United Kingdom
# 25                   Allentown, PA  40.60843  -75.49018         United States
# 26         Cape Town, South Africa -33.92584   18.42322          South Africa
# 27              Newark, New Jersey  40.73566  -74.17237         United States
# 28                             NaN       NaN        NaN                   NaN
# 29                   New York City  40.71427  -74.00597         United States
# ...                            ...       ...        ...                   ...
# 11917                          NaN       NaN        NaN                   NaN
# 11918               ᴄʀᴏᴄᴏᴅɪʟᴇ ɪsʟᴇ   0.00000    0.00000                  FAKE
# 11919                          NaN       NaN        NaN                   NaN
# 11920                          NaN       NaN        NaN                   NaN
# 11921                  Los Angeles  34.05223 -118.24368         United States
# 11922          Manchester, England  53.48095   -2.23743        United Kingdom
# 11923                       Global  25.06765   55.30557  United Arab Emirates
# 11924                          NaN       NaN        NaN                   NaN
# 11925                          NaN       NaN        NaN                   NaN
# 11926                        Ελλάς   0.00000    0.00000                  FAKE
# 11927               Lokoja Nigeria   7.79688    6.74048               Nigeria
# 11928             Toronto, Ontario  43.70011  -79.41630                Canada
# 11929                     Brooklyn  40.65010  -73.94958         United States
# 11930                  Los Angeles  34.05223 -118.24368         United States
# 11931                   Ottawa, ON  45.41117  -75.69812                Canada
# 11932                Arlington, TX  32.73569  -97.10807         United States
# 11933              London, England  51.50853   -0.12574        United Kingdom
# 11934                United States  39.76000  -98.50000         United States
# 11935   If i knew i would tell you   0.00000    0.00000                  FAKE
# 11936                          NaN       NaN        NaN                   NaN
# 11937       In my Studio working.    0.00000    0.00000                  FAKE
# 11938                          NaN       NaN        NaN                   NaN
# 11939  San Luis Obispo, California  35.28275 -120.65962         United States
# 11940    In Glamourous California    0.00000    0.00000                  FAKE
# 11941                          NaN       NaN        NaN                   NaN
# 11942                          NaN       NaN        NaN                   NaN
# 11943                          NaN       NaN        NaN                   NaN
# 11944                   Denver, CO  39.73915 -104.98470         United States
# 11945             Ass Cheek Valley   0.00000    0.00000                  FAKE
# 11946                     Colorado  38.83388 -104.82136         United States
#
#       created_at  followers_count  friends_count  statuses_count  \
# 0            NaN              NaN            NaN             NaN
# 1        2013-04           1204.0          840.0         19352.0
# 2        2011-08            635.0          577.0          7853.0
# 3        2013-06           2372.0         2433.0        188053.0
# 4        2015-12           1251.0          994.0         37579.0
# 5        2008-12            334.0          503.0          5519.0
# 6        2016-04             69.0           70.0          9725.0
# 7        2010-08            370.0         1884.0         56506.0
# 8        2009-07            765.0         1094.0         39817.0
# 9        2011-02            774.0         1395.0         19460.0
# 10       2016-01            290.0          407.0           783.0
# 11       2013-07            113.0           59.0          7690.0
# 12       2014-10             58.0          326.0          3952.0
# 13       2013-12          47400.0        24243.0         12518.0
# 14       2010-01            348.0          785.0          5710.0
# 15       2015-07            344.0          134.0          4559.0
# 16       2012-04            432.0          418.0         42476.0
# 17       2014-04             87.0           45.0           155.0
# 18       2011-08            395.0          827.0         82088.0
# 19       2009-09             90.0          189.0         12384.0
# 20       2013-09             16.0           42.0            55.0
# 21       2014-02            437.0          474.0         25765.0
# 22       2014-10            171.0          398.0          1203.0
# 23       2011-12            221.0          169.0         10795.0
# 24       2014-06           5939.0         1775.0          3333.0
# 25       2013-01            154.0          246.0          3011.0
# 26       2009-04            536.0         1245.0         32190.0
# 27       2015-08             17.0           43.0            75.0
# 28       2011-10            537.0         3788.0          1371.0
# 29       2014-12             68.0          140.0           463.0
# ...          ...              ...            ...             ...
# 11917    2013-06             19.0           74.0           737.0
# 11918    2014-04            399.0          198.0            13.0
# 11919    2015-04             60.0           95.0           964.0
# 11920        NaN              NaN            NaN             NaN
# 11921    2009-04            248.0           68.0          6318.0
# 11922    2009-03            638.0         1114.0          8563.0
# 11923    2011-09            385.0          205.0        117125.0
# 11924    2010-03            929.0          321.0         87645.0
# 11925    2015-09            686.0           74.0        202413.0
# 11926    2012-07           6221.0          145.0         74172.0
# 11927    2013-01             51.0           64.0          1419.0
# 11928    2012-04            332.0          837.0          5967.0
# 11929    2012-07           2130.0         3058.0          1553.0
# 11930    2014-04          31202.0         8528.0         18277.0
# 11931    2008-10          31861.0           81.0         54721.0
# 11932    2013-10            151.0          252.0          9587.0
# 11933    2009-09            918.0         1766.0         24707.0
# 11934    2015-11              2.0            1.0           155.0
# 11935    2009-04            304.0          299.0         27163.0
# 11936    2012-02             98.0          151.0          3647.0
# 11937    2008-07           3112.0         1996.0         15185.0
# 11938        NaN              NaN            NaN             NaN
# 11939    2009-05            365.0          631.0         30669.0
# 11940    2009-03            157.0          136.0          8820.0
# 11941    2011-02            175.0          362.0          8291.0
# 11942    2015-09          37919.0         1187.0        170239.0
# 11943        NaN              NaN            NaN             NaN
# 11944    2014-09           5136.0         4513.0         11428.0
# 11945    2013-12            114.0          816.0          1872.0
# 11946    2010-04              3.0           23.0           266.0
#
#        favourites_count  listed_count
# 0                   NaN           NaN
# 1                7195.0         114.0
# 2                1141.0          28.0
# 3               88471.0          68.0
# 4               27530.0          77.0
# 5                8125.0          56.0
# 6                  37.0          89.0
# 7              133174.0          28.0
# 8               70564.0          54.0
# 9                9515.0          30.0
# 10                417.0           8.0
# 11               5954.0           2.0
# 12               8213.0           3.0
# 13               1987.0         239.0
# 14                712.0          23.0
# 15              10752.0           0.0
# 16              12407.0           5.0
# 17                 18.0          12.0
# 18              13244.0          15.0
# 19                  4.0          10.0
# 20                 63.0           0.0
# 21               1465.0          12.0
# 22                707.0           3.0
# 23               2612.0           1.0
# 24                181.0         363.0
# 25                799.0           7.0
# 26               5162.0          30.0
# 27                 13.0           0.0
# 28               2985.0           9.0
# 29                  6.0           3.0
# ...                 ...           ...
# 11917            2136.0           5.0
# 11918               2.0           1.0
# 11919             310.0           1.0
# 11920               NaN           NaN
# 11921             307.0           6.0
# 11922            3417.0          64.0
# 11923             139.0          34.0
# 11924             410.0          14.0
# 11925               0.0        1047.0
# 11926           10911.0          25.0
# 11927             752.0           4.0
# 11928           14240.0          34.0
# 11929            1724.0          45.0
# 11930           14909.0         174.0
# 11931             149.0         575.0
# 11932           21426.0           0.0
# 11933            2305.0          54.0
# 11934               1.0           1.0
# 11935            1435.0           2.0
# 11936             507.0           4.0
# 11937              62.0          64.0
# 11938               NaN           NaN
# 11939            4190.0          37.0
# 11940            1752.0           4.0
# 11941            2713.0          65.0
# 11942              41.0         115.0
# 11943               NaN           NaN
# 11944            1695.0         555.0
# 11945            1015.0           1.0
# 11946             326.0           2.0
#
# [11947 rows x 16 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Для того, чтобы лучше понять, как устроена наша обучающая выборка, построим несколько графиков. Сначала построим долю "положительных" пользователей в зависимости от дня создания аккаунта. По горизонтальной оси отложим день создания аккаунта, а по вертикальной -- долю "положительных" пользователей ([подсказка](http://stroykova.github.io/sphera/l1_1.png)). Необходимо дописать код функции count_users. В функции необходимо посчитать пользователей в каждой группе (1 балл).

# %%
def count_users(grouped):
    """
    Counts number of positive and negative users
    created at eac date.
    
    Returns:
        count_pos -- 1D numpy array with the counts of positive users created at each date
        count_neg -- 1D numpy array with the counts of negative users created at each date
        dts -- a list of date strings, e.g. ['2014-10', '2014-11', ...]
    """
    dts = []
    count_pos, count_neg = np.zeros(len(grouped)), np.zeros(len(grouped))
    # your code here
    for name, group in grouped:
        dts.append(name)
        count_pos[len(dts) - 1] = sum(group['cls'])
        count_neg[len(dts) - 1] = len(group['cls']) - sum(group['cls'])
    return count_pos, count_neg, dts


grouped = df_full.groupby(map(lambda dt: dt if pd.notnull(dt) else "NA", df_full["created_at"]))
count_pos, count_neg, dts = count_users(grouped)
    
fraction_pos = count_pos / (count_pos + count_neg + 1e-10)
fraction_neg = 1 - fraction_pos

sort_ind = np.argsort(dts)
    
pl.figure(figsize=(20, 3))
pl.bar(np.arange(len(dts)), fraction_pos[sort_ind], width=1.0, color='red', alpha=0.6, linewidth=0, label="Positive")
pl.bar(np.arange(len(dts)), fraction_neg[sort_ind], bottom=fraction_pos[sort_ind], width=1.0, color='green', alpha=0.6, linewidth=0, label="Negative")
pl.xticks(np.arange(len(dts)) + 0.4, sorted(dts), rotation=90)
pl.title("Class distribution by account creation month")
pl.xlim(0, len(dts))
pl.legend()
pl.show()

# %% [markdown]
# Видно, что доля "положительных" аккаунтов в выборке растет с увеличением времени. Посмотрим, где живут пользователи положительной и отрицательной категории. Для этого отметим на карте каждого положительного пользователя красным, а отрицательного -- зеленым цветом ([подсказка](http://stroykova.github.io/sphera/l1_2.png)). Необходимо реализовать функцию plot_points_on_map. В функции необходимо отобразить на карте пользователей из разных классов (2 балла).

# %%
df_full = pd.read_csv('save.csv', sep='\t')

# %%
pl.figure(figsize=(40,24))

m = bm.Basemap(projection='cyl', llcrnrlat=-90, urcrnrlat=90, llcrnrlon=-180, urcrnrlon=180, resolution='c')

m.drawcountries(linewidth=0.2)
m.fillcontinents(color='lavender', lake_color='#000040')
m.drawmapboundary(linewidth=0.2, fill_color='#000040')
m.drawparallels(np.arange(-90,90,30),labels=[0,0,0,0], color='white', linewidth=0.5)
m.drawmeridians(np.arange(0,360,30),labels=[0,0,0,0], color='white', linewidth=0.5)

def plot_points_on_map(df_full):
    """
    Plot points on the map. Be creative.
    """
    Loc = {}
    grouped = df_full.groupby((df_full['lon'], df_full['lat'], df_full['cls']))
    for name, group in grouped:
        x, y = name[0:2]
        x, y = float(x), float(y)
        if not (x, y) in Loc:
            #print type(x), type(y)
            Loc[(x, y)] = [0, 0]
        Loc[(x, y)][int(name[2])] += len(group)
    
    for i in Loc:
        x = i[0]
        y = i[1]
        sz = x + y
        gr = hex(min(255, Loc[i][0] * 100))[2:]
        re = hex(min(255, Loc[i][1] * 100))[2:]
        if len(gr) < 2:
            gr = '0' + gr
        if len(re) < 2:
            re = '0' + re
        color = '#{}{}00'.format(re, gr)
        m.plot(x, y, 'bo', markersize=max(4, sz/15), color=color)
    return
plot_points_on_map(df_full)

pl.title("Geospatial distribution of twitter users")
pl.legend()
pl.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# В последней картинке есть проблема: сервис геоинформации определяет координаты с точностью до города, поэтому точки, соответствующте нескольким пользователям, могут накладываться. Предложите и реализуйте способ, позволяющий справиться с этой проблемой (2 балла).

# %% [markdown]
# В поле ниже необходимо словами описать, как было улучшено изображение (описание необходимо для корректной проверки задания).

# %% [markdown]
# На изображении сделаны следующие улучшения:
# * Чем больше людей одного класса попали в одну точку, чем ярче оттенок цвета класса (желтый это значит много и красных и зеленых)
# * Чем больше суммарное количество людей, тем больше размер самой точки (в Америке все распределены по разным городам, а в России все кто есть, все в Москве)

# %% [markdown]
# #### Опредилим пользователи какого класса популярнее, а именно пользователи какого класса имеют больше фолловеров.
#
# Для этого
#     1. Посчитайте дескриптивные статистики для признака followers_count -- min, max, mean и median
#     2. Постройте гистограммы для пользователей двух классов.
# [подсказка](http://stroykova.github.io/sphera/l1_3.png)
#     3. На основе полученных данных ответьте на вопросы
#         1. Почему mean и median имеют разные значения? Потому что, большинство имеет низкое количество фоловеров, а медиана смотрит именно на то где по количеству половина. А среднее просто среднее, просто есть люди у которых очень много и среднее сдвигается от большинтсва.
#         2. Пользователи какого класса популярнее? Одинаково, невозможно определить, от генерации других случайных значений распределение может меняться то в сторону одних, то в сторону других.
# Подсказка: так как пользователей позитивного класса в 3.5 раза больше, чем негативного прежде чем приступать к анализу необходимо случайным образом выбрать по N(N>=500) пользователей негативного и позитивного классов. (1 балл)

# %%
sample_number = 500
users_wth_neg_class = df_full[df_full["cls"]==0].sample(sample_number)
users_wth_pos_class = df_full[df_full["cls"]==1].sample(sample_number)

def descriptive_stat_and_hist(users_wth_neg_class, users_wth_pos_class):
    print "min:", np.min(users_wth_neg_class['followers_count']), np.min(users_wth_pos_class['followers_count'])
    print "max:", np.max(users_wth_neg_class['followers_count']), np.max(users_wth_pos_class['followers_count'])
    print "mean:", np.mean(users_wth_neg_class['followers_count']), np.mean(users_wth_pos_class['followers_count'])
    print "median:", np.nanmedian(users_wth_neg_class['followers_count']), np.nanmedian(users_wth_pos_class['followers_count'])
    #Calculate min max and median. Plot histogram
        #Your code her

    followers_neg = users_wth_neg_class['followers_count'].dropna()
    followers_pos = users_wth_pos_class['followers_count'].dropna()
    n, _, patches = pl.hist([followers_neg, followers_pos], 
                            label = ["negative", "positive"], 
                            bins=[x for x in xrange(0, int(max(followers_neg.max(), followers_pos.max()) ), 
                                                    int(max(followers_neg.max(), followers_pos.max()) ) / 15)]
                           )
    pl.show()
    
    return

descriptive_stat_and_hist(users_wth_neg_class, users_wth_pos_class)
# Out:
# min: 4.0 0.0
# max: 138168.0 294559.0
# mean: 2662.28169014 3302.75506073
# median: 384.0 336.5

# %% [markdown]
# Смотрим на полученный data frame и сохраняем его в .csv файл.

# %%
OUT_FILE_PATH = "hw1_out.csv"
print "Saving output data frame to %s" % OUT_FILE_PATH
df_full.to_csv(OUT_FILE_PATH, sep="\t", index=False, encoding="utf-8", quoting=csv.QUOTE_NONNUMERIC)
df_full.head()
# Out:
# Saving output data frame to hw1_out.csv
#           uid  cls               name    screen_name  \
# 0   202388889  1.0                NaN            NaN
# 1  1392518336  0.0       Tomboy Tarts    TomboyTarts
# 2   361208576  1.0      THE MANC GEEK       BigA85GL
# 3  1535215357  1.0              L 🎃 🍂    laurynjiles
# 4  4396196375  1.0  #1stEdifyToUplift  EdifyToUplift
#
#                                          description verified  \
# 0                                                NaN      NaN
# 1  Celebrating the classic tomboy spirit with a b...    False
# 2  Mancunian geek, blogger/writer/reviewer. Consu...    False
# 3  I'll be waiting here for you on this New York ...    False
# 4  Awareness.Advocacy.Ascend🎈• Building awareness...    False
#
#                   location       lat        lon         country created_at  \
# 0                      NaN       NaN        NaN             NaN        NaN
# 1      Singapore/Malaysia    1.54860  103.52690        Malaysia    2013-04
# 2           Manchester, UK  53.48095   -2.23743  United Kingdom    2011-08
# 3             Marvel. DC.    0.00000    0.00000            FAKE    2013-06
# 4  God is my refuge; gem❤️   0.00000    0.00000            FAKE    2015-12
#
#    followers_count  friends_count  statuses_count  favourites_count  \
# 0              NaN            NaN             NaN               NaN
# 1           1204.0          840.0         19352.0            7195.0
# 2            635.0          577.0          7853.0            1141.0
# 3           2372.0         2433.0        188053.0           88471.0
# 4           1251.0          994.0         37579.0           27530.0
#
#    listed_count
# 0           NaN
# 1         114.0
# 2          28.0
# 3          68.0
# 4          77.0
